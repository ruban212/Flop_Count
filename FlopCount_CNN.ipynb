# %%
import torch
import torchvision.models as models
from fvcore.nn import FlopCountAnalysis

model = models.resnet50(pretrained=True)
model.eval()

input_tensor = torch.randn(1, 3, 224, 224)

flops = FlopCountAnalysis(model, input_tensor)
print(f"FLOPs: {flops.total()}")
# Out:
# C:\Users\mruba\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\mruba\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to C:\Users\mruba/.cache\torch\hub\checkpoints\resnet50-0676ba61.pth
# 100%|█████████████████████████████████████████████████████████████████████████████| 97.8M/97.8M [00:15<00:00, 6.73MB/s]
# Unsupported operator aten::max_pool2d encountered 1 time(s)
# Unsupported operator aten::add_ encountered 16 time(s)
# FLOPs: 4111512576

# %%
from ptflops import get_model_complexity_info

model = models.resnet50(pretrained=True)

macs, params = get_model_complexity_info(model, (3, 224, 224), as_strings=True, print_per_layer_stat=True)
print(f"FLOPs: {macs}, Parameters: {params}")
# Out:
# C:\Users\mruba\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\mruba\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ResNet(
#   25.56 M, 100.000% Params, 4.12 GMac, 99.746% MACs,
#   (conv1): Conv2d(9.41 k, 0.037% Params, 118.01 MMac, 2.856% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(128, 0.001% Params, 1.61 MMac, 0.039% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(0, 0.000% Params, 802.82 KMac, 0.019% MACs, inplace=True)
#   (maxpool): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.019% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     215.81 k, 0.844% Params, 680.39 MMac, 16.465% MACs,
#     (0): Bottleneck(
#       75.01 k, 0.293% Params, 236.43 MMac, 5.721% MACs,
#       (conv1): Conv2d(4.1 k, 0.016% Params, 12.85 MMac, 0.311% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.010% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(36.86 k, 0.144% Params, 115.61 MMac, 2.798% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.010% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(16.38 k, 0.064% Params, 51.38 MMac, 1.243% MACs, 64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, 0.002% Params, 1.61 MMac, 0.039% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 1.2 MMac, 0.029% MACs, inplace=True)
#       (downsample): Sequential(
#         16.9 k, 0.066% Params, 52.99 MMac, 1.282% MACs,
#         (0): Conv2d(16.38 k, 0.064% Params, 51.38 MMac, 1.243% MACs, 64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(512, 0.002% Params, 1.61 MMac, 0.039% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       70.4 k, 0.275% Params, 221.98 MMac, 5.372% MACs,
#       (conv1): Conv2d(16.38 k, 0.064% Params, 51.38 MMac, 1.243% MACs, 256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.010% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(36.86 k, 0.144% Params, 115.61 MMac, 2.798% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.010% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(16.38 k, 0.064% Params, 51.38 MMac, 1.243% MACs, 64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, 0.002% Params, 1.61 MMac, 0.039% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 1.2 MMac, 0.029% MACs, inplace=True)
#     )
#     (2): Bottleneck(
#       70.4 k, 0.275% Params, 221.98 MMac, 5.372% MACs,
#       (conv1): Conv2d(16.38 k, 0.064% Params, 51.38 MMac, 1.243% MACs, 256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.010% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(36.86 k, 0.144% Params, 115.61 MMac, 2.798% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.010% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(16.38 k, 0.064% Params, 51.38 MMac, 1.243% MACs, 64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, 0.002% Params, 1.61 MMac, 0.039% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 1.2 MMac, 0.029% MACs, inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     1.22 M, 4.772% Params, 1.04 GMac, 25.083% MACs,
#     (0): Bottleneck(
#       379.39 k, 1.484% Params, 376.02 MMac, 9.099% MACs,
#       (conv1): Conv2d(32.77 k, 0.128% Params, 102.76 MMac, 2.487% MACs, 256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, 0.001% Params, 802.82 KMac, 0.019% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(147.46 k, 0.577% Params, 115.61 MMac, 2.798% MACs, 128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.005% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(65.54 k, 0.256% Params, 51.38 MMac, 1.243% MACs, 128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1.02 k, 0.004% Params, 802.82 KMac, 0.019% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 903.17 KMac, 0.022% MACs, inplace=True)
#       (downsample): Sequential(
#         132.1 k, 0.517% Params, 103.56 MMac, 2.506% MACs,
#         (0): Conv2d(131.07 k, 0.513% Params, 102.76 MMac, 2.487% MACs, 256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1.02 k, 0.004% Params, 802.82 KMac, 0.019% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       280.06 k, 1.096% Params, 220.17 MMac, 5.328% MACs,
#       (conv1): Conv2d(65.54 k, 0.256% Params, 51.38 MMac, 1.243% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.005% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(147.46 k, 0.577% Params, 115.61 MMac, 2.798% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.005% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(65.54 k, 0.256% Params, 51.38 MMac, 1.243% MACs, 128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1.02 k, 0.004% Params, 802.82 KMac, 0.019% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 602.11 KMac, 0.015% MACs, inplace=True)
#     )
#     (2): Bottleneck(
#       280.06 k, 1.096% Params, 220.17 MMac, 5.328% MACs,
#       (conv1): Conv2d(65.54 k, 0.256% Params, 51.38 MMac, 1.243% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.005% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(147.46 k, 0.577% Params, 115.61 MMac, 2.798% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.005% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(65.54 k, 0.256% Params, 51.38 MMac, 1.243% MACs, 128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1.02 k, 0.004% Params, 802.82 KMac, 0.019% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 602.11 KMac, 0.015% MACs, inplace=True)
#     )
#     (3): Bottleneck(
#       280.06 k, 1.096% Params, 220.17 MMac, 5.328% MACs,
#       (conv1): Conv2d(65.54 k, 0.256% Params, 51.38 MMac, 1.243% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.005% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(147.46 k, 0.577% Params, 115.61 MMac, 2.798% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, 0.001% Params, 200.7 KMac, 0.005% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(65.54 k, 0.256% Params, 51.38 MMac, 1.243% MACs, 128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1.02 k, 0.004% Params, 802.82 KMac, 0.019% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 602.11 KMac, 0.015% MACs, inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     7.1 M, 27.775% Params, 1.47 GMac, 35.587% MACs,
#     (0): Bottleneck(
#       1.51 M, 5.918% Params, 374.26 MMac, 9.057% MACs,
#       (conv1): Conv2d(131.07 k, 0.513% Params, 102.76 MMac, 2.487% MACs, 512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, 0.002% Params, 401.41 KMac, 0.010% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(589.82 k, 2.308% Params, 115.61 MMac, 2.798% MACs, 256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.002% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(262.14 k, 1.026% Params, 51.38 MMac, 1.243% MACs, 256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2.05 k, 0.008% Params, 401.41 KMac, 0.010% MACs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 451.58 KMac, 0.011% MACs, inplace=True)
#       (downsample): Sequential(
#         526.34 k, 2.059% Params, 103.16 MMac, 2.496% MACs,
#         (0): Conv2d(524.29 k, 2.051% Params, 102.76 MMac, 2.487% MACs, 512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2.05 k, 0.008% Params, 401.41 KMac, 0.010% MACs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       1.12 M, 4.371% Params, 219.27 MMac, 5.306% MACs,
#       (conv1): Conv2d(262.14 k, 1.026% Params, 51.38 MMac, 1.243% MACs, 1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.002% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(589.82 k, 2.308% Params, 115.61 MMac, 2.798% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.002% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(262.14 k, 1.026% Params, 51.38 MMac, 1.243% MACs, 256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2.05 k, 0.008% Params, 401.41 KMac, 0.010% MACs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 301.06 KMac, 0.007% MACs, inplace=True)
#     )
#     (2): Bottleneck(
#       1.12 M, 4.371% Params, 219.27 MMac, 5.306% MACs,
#       (conv1): Conv2d(262.14 k, 1.026% Params, 51.38 MMac, 1.243% MACs, 1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.002% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(589.82 k, 2.308% Params, 115.61 MMac, 2.798% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.002% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(262.14 k, 1.026% Params, 51.38 MMac, 1.243% MACs, 256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2.05 k, 0.008% Params, 401.41 KMac, 0.010% MACs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 301.06 KMac, 0.007% MACs, inplace=True)
#     )
#     (3): Bottleneck(
#       1.12 M, 4.371% Params, 219.27 MMac, 5.306% MACs,
#       (conv1): Conv2d(262.14 k, 1.026% Params, 51.38 MMac, 1.243% MACs, 1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.002% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(589.82 k, 2.308% Params, 115.61 MMac, 2.798% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.002% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(262.14 k, 1.026% Params, 51.38 MMac, 1.243% MACs, 256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2.05 k, 0.008% Params, 401.41 KMac, 0.010% MACs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 301.06 KMac, 0.007% MACs, inplace=True)
#     )
#     (4): Bottleneck(
#       1.12 M, 4.371% Params, 219.27 MMac, 5.306% MACs,
#       (conv1): Conv2d(262.14 k, 1.026% Params, 51.38 MMac, 1.243% MACs, 1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.002% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(589.82 k, 2.308% Params, 115.61 MMac, 2.798% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.002% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(262.14 k, 1.026% Params, 51.38 MMac, 1.243% MACs, 256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2.05 k, 0.008% Params, 401.41 KMac, 0.010% MACs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 301.06 KMac, 0.007% MACs, inplace=True)
#     )
#     (5): Bottleneck(
#       1.12 M, 4.371% Params, 219.27 MMac, 5.306% MACs,
#       (conv1): Conv2d(262.14 k, 1.026% Params, 51.38 MMac, 1.243% MACs, 1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.002% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(589.82 k, 2.308% Params, 115.61 MMac, 2.798% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, 0.002% Params, 100.35 KMac, 0.002% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(262.14 k, 1.026% Params, 51.38 MMac, 1.243% MACs, 256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2.05 k, 0.008% Params, 401.41 KMac, 0.010% MACs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 301.06 KMac, 0.007% MACs, inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     14.96 M, 58.554% Params, 811.02 MMac, 19.626% MACs,
#     (0): Bottleneck(
#       6.04 M, 23.632% Params, 373.38 MMac, 9.035% MACs,
#       (conv1): Conv2d(524.29 k, 2.051% Params, 102.76 MMac, 2.487% MACs, 1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1.02 k, 0.004% Params, 200.7 KMac, 0.005% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(2.36 M, 9.231% Params, 115.61 MMac, 2.798% MACs, 512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(1.02 k, 0.004% Params, 50.18 KMac, 0.001% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1.05 M, 4.103% Params, 51.38 MMac, 1.243% MACs, 512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(4.1 k, 0.016% Params, 200.7 KMac, 0.005% MACs, 2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 225.79 KMac, 0.005% MACs, inplace=True)
#       (downsample): Sequential(
#         2.1 M, 8.222% Params, 102.96 MMac, 2.492% MACs,
#         (0): Conv2d(2.1 M, 8.206% Params, 102.76 MMac, 2.487% MACs, 1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(4.1 k, 0.016% Params, 200.7 KMac, 0.005% MACs, 2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       4.46 M, 17.461% Params, 218.82 MMac, 5.295% MACs,
#       (conv1): Conv2d(1.05 M, 4.103% Params, 51.38 MMac, 1.243% MACs, 2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1.02 k, 0.004% Params, 50.18 KMac, 0.001% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(2.36 M, 9.231% Params, 115.61 MMac, 2.798% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(1.02 k, 0.004% Params, 50.18 KMac, 0.001% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1.05 M, 4.103% Params, 51.38 MMac, 1.243% MACs, 512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(4.1 k, 0.016% Params, 200.7 KMac, 0.005% MACs, 2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 150.53 KMac, 0.004% MACs, inplace=True)
#     )
#     (2): Bottleneck(
#       4.46 M, 17.461% Params, 218.82 MMac, 5.295% MACs,
#       (conv1): Conv2d(1.05 M, 4.103% Params, 51.38 MMac, 1.243% MACs, 2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1.02 k, 0.004% Params, 50.18 KMac, 0.001% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(2.36 M, 9.231% Params, 115.61 MMac, 2.798% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(1.02 k, 0.004% Params, 50.18 KMac, 0.001% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1.05 M, 4.103% Params, 51.38 MMac, 1.243% MACs, 512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(4.1 k, 0.016% Params, 200.7 KMac, 0.005% MACs, 2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 150.53 KMac, 0.004% MACs, inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 100.35 KMac, 0.002% MACs, output_size=(1, 1))
#   (fc): Linear(2.05 M, 8.017% Params, 2.05 MMac, 0.050% MACs, in_features=2048, out_features=1000, bias=True)
# )
# FLOPs: 4.13 GMac, Parameters: 25.56 M

# %%
import torchvision.models as models
from fvcore.nn import FlopCountAnalysis

model_list = [models.resnet50, models.vgg16, models.efficientnet_b0, models.inception_v3]

for model_fn in model_list:
    model = model_fn(pretrained=True)
    model.eval()
    input_tensor = torch.randn(1, 3, 224, 224)
    
    if model_fn == models.inception_v3: 
        input_tensor = torch.randn(1, 3, 299, 299)
    
    flops = FlopCountAnalysis(model, input_tensor)
    print(f"{model_fn.__name__}: FLOPs = {flops.total()}")
# Out:
# Unsupported operator aten::max_pool2d encountered 1 time(s)
# Unsupported operator aten::add_ encountered 16 time(s)
# C:\Users\mruba\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\mruba\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# resnet50: FLOPs = 4111512576
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to C:\Users\mruba/.cache\torch\hub\checkpoints\vgg16-397923af.pth
# 100%|███████████████████████████████████████████████████████████████████████████████| 528M/528M [01:37<00:00, 5.66MB/s]
# Unsupported operator aten::max_pool2d encountered 5 time(s)
# C:\Users\mruba\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\mruba\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# vgg16: FLOPs = 15470289408
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to C:\Users\mruba/.cache\torch\hub\checkpoints\efficientnet_b0_rwightman-7f5810bc.pth
# 100%|█████████████████████████████████████████████████████████████████████████████| 20.5M/20.5M [00:02<00:00, 7.83MB/s]
# Unsupported operator aten::silu_ encountered 49 time(s)
# Unsupported operator aten::sigmoid encountered 16 time(s)
# Unsupported operator aten::mul encountered 16 time(s)
# Unsupported operator aten::add_ encountered 9 time(s)
# Unsupported operator aten::dropout_ encountered 1 time(s)
# The following submodules of the model were never called during the trace of the graph. They may be unused, or they were accessed by direct calls to .forward() or via other python methods. In the latter case they will have zeros for statistics, though their statistics will still contribute to their parent calling module.
# features.1.0.stochastic_depth, features.2.0.stochastic_depth, features.2.1.stochastic_depth, features.3.0.stochastic_depth, features.3.1.stochastic_depth, features.4.0.stochastic_depth, features.4.1.stochastic_depth, features.4.2.stochastic_depth, features.5.0.stochastic_depth, features.5.1.stochastic_depth, features.5.2.stochastic_depth, features.6.0.stochastic_depth, features.6.1.stochastic_depth, features.6.2.stochastic_depth, features.6.3.stochastic_depth, features.7.0.stochastic_depth
# C:\Users\mruba\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\mruba\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# efficientnet_b0: FLOPs = 401659392
# Downloading: "https://download.pytorch.org/models/inception_v3_google-0cc3c7bd.pth" to C:\Users\mruba/.cache\torch\hub\checkpoints\inception_v3_google-0cc3c7bd.pth
# 100%|███████████████████████████████████████████████████████████████████████████████| 104M/104M [00:16<00:00, 6.76MB/s]
# Unsupported operator aten::mul encountered 3 time(s)
# Unsupported operator aten::add encountered 3 time(s)
# Unsupported operator aten::max_pool2d encountered 4 time(s)
# Unsupported operator aten::avg_pool2d encountered 9 time(s)
# The following submodules of the model were never called during the trace of the graph. They may be unused, or they were accessed by direct calls to .forward() or via other python methods. In the latter case they will have zeros for statistics, though their statistics will still contribute to their parent calling module.
# AuxLogits, AuxLogits.conv0, AuxLogits.conv0.bn, AuxLogits.conv0.conv, AuxLogits.conv1, AuxLogits.conv1.bn, AuxLogits.conv1.conv, AuxLogits.fc
# inception_v3: FLOPs = 5731282144

# %%
from ptflops import get_model_complexity_info

# Example with ResNet-50
model = models.vgg16(pretrained=True)

# Input dimensions
macs, params = get_model_complexity_info(model, (3, 224, 224), as_strings=True, print_per_layer_stat=True)
print(f"FLOPs: {macs}, Parameters: {params}")
# Out:
# VGG(
#   138.36 M, 100.000% Params, 15.5 GMac, 99.873% MACs,
#   (features): Sequential(
#     14.71 M, 10.635% Params, 15.38 GMac, 99.076% MACs,
#     (0): Conv2d(1.79 k, 0.001% Params, 89.92 MMac, 0.579% MACs, 3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(0, 0.000% Params, 3.21 MMac, 0.021% MACs, inplace=True)
#     (2): Conv2d(36.93 k, 0.027% Params, 1.85 GMac, 11.936% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(0, 0.000% Params, 3.21 MMac, 0.021% MACs, inplace=True)
#     (4): MaxPool2d(0, 0.000% Params, 3.21 MMac, 0.021% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(73.86 k, 0.053% Params, 926.45 MMac, 5.968% MACs, 64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(0, 0.000% Params, 1.61 MMac, 0.010% MACs, inplace=True)
#     (7): Conv2d(147.58 k, 0.107% Params, 1.85 GMac, 11.926% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(0, 0.000% Params, 1.61 MMac, 0.010% MACs, inplace=True)
#     (9): MaxPool2d(0, 0.000% Params, 1.61 MMac, 0.010% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(295.17 k, 0.213% Params, 925.65 MMac, 5.963% MACs, 128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(0, 0.000% Params, 802.82 KMac, 0.005% MACs, inplace=True)
#     (12): Conv2d(590.08 k, 0.426% Params, 1.85 GMac, 11.921% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(0, 0.000% Params, 802.82 KMac, 0.005% MACs, inplace=True)
#     (14): Conv2d(590.08 k, 0.426% Params, 1.85 GMac, 11.921% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(0, 0.000% Params, 802.82 KMac, 0.005% MACs, inplace=True)
#     (16): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.005% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(1.18 M, 0.853% Params, 925.25 MMac, 5.960% MACs, 256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(0, 0.000% Params, 401.41 KMac, 0.003% MACs, inplace=True)
#     (19): Conv2d(2.36 M, 1.706% Params, 1.85 GMac, 11.918% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(0, 0.000% Params, 401.41 KMac, 0.003% MACs, inplace=True)
#     (21): Conv2d(2.36 M, 1.706% Params, 1.85 GMac, 11.918% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(0, 0.000% Params, 401.41 KMac, 0.003% MACs, inplace=True)
#     (23): MaxPool2d(0, 0.000% Params, 401.41 KMac, 0.003% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(2.36 M, 1.706% Params, 462.52 MMac, 2.980% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(0, 0.000% Params, 100.35 KMac, 0.001% MACs, inplace=True)
#     (26): Conv2d(2.36 M, 1.706% Params, 462.52 MMac, 2.980% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(0, 0.000% Params, 100.35 KMac, 0.001% MACs, inplace=True)
#     (28): Conv2d(2.36 M, 1.706% Params, 462.52 MMac, 2.980% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(0, 0.000% Params, 100.35 KMac, 0.001% MACs, inplace=True)
#     (30): MaxPool2d(0, 0.000% Params, 100.35 KMac, 0.001% MACs, kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 25.09 KMac, 0.000% MACs, output_size=(7, 7))
#   (classifier): Sequential(
#     123.64 M, 89.365% Params, 123.65 MMac, 0.797% MACs,
#     (0): Linear(102.76 M, 74.275% Params, 102.76 MMac, 0.662% MACs, in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(0, 0.000% Params, 4.1 KMac, 0.000% MACs, inplace=True)
#     (2): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.5, inplace=False)
#     (3): Linear(16.78 M, 12.129% Params, 16.78 MMac, 0.108% MACs, in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(0, 0.000% Params, 4.1 KMac, 0.000% MACs, inplace=True)
#     (5): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.5, inplace=False)
#     (6): Linear(4.1 M, 2.961% Params, 4.1 MMac, 0.026% MACs, in_features=4096, out_features=1000, bias=True)
#   )
# )
# FLOPs: 15.52 GMac, Parameters: 138.36 M

# %%
from ptflops import get_model_complexity_info

# Example with ResNet-50
model = models.efficientnet_b0(pretrained=True)

# Input dimensions
macs, params = get_model_complexity_info(model, (3, 224, 224), as_strings=True, print_per_layer_stat=True)
print(f"FLOPs: {macs}, Parameters: {params}")
# Out:
# C:\Users\mruba\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# EfficientNet(
#   5.29 M, 100.000% Params, 401.67 MMac, 97.921% MACs,
#   (features): Sequential(
#     4.01 M, 75.778% Params, 400.33 MMac, 97.594% MACs,
#     (0): Conv2dNormActivation(
#       928, 0.018% Params, 11.64 MMac, 2.838% MACs,
#       (0): Conv2d(864, 0.016% Params, 10.84 MMac, 2.642% MACs, 3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, 0.001% Params, 802.82 KMac, 0.196% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#     )
#     (1): Sequential(
#       1.45 k, 0.027% Params, 11.64 MMac, 2.838% MACs,
#       (0): MBConv(
#         1.45 k, 0.027% Params, 11.64 MMac, 2.838% MACs,
#         (block): Sequential(
#           1.45 k, 0.027% Params, 11.64 MMac, 2.838% MACs,
#           (0): Conv2dNormActivation(
#             352, 0.007% Params, 4.42 MMac, 1.076% MACs,
#             (0): Conv2d(288, 0.005% Params, 3.61 MMac, 0.881% MACs, 32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(64, 0.001% Params, 802.82 KMac, 0.196% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): SqueezeExcitation(
#             552, 0.010% Params, 401.96 KMac, 0.098% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 401.41 KMac, 0.098% MACs, output_size=1)
#             (fc1): Conv2d(264, 0.005% Params, 264.0 Mac, 0.000% MACs, 32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(288, 0.005% Params, 288.0 Mac, 0.000% MACs, 8, 32, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (2): Conv2dNormActivation(
#             544, 0.010% Params, 6.82 MMac, 1.664% MACs,
#             (0): Conv2d(512, 0.010% Params, 6.42 MMac, 1.566% MACs, 32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(32, 0.001% Params, 401.41 KMac, 0.098% MACs, 16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#     )
#     (2): Sequential(
#       16.71 k, 0.316% Params, 60.82 MMac, 14.826% MACs,
#       (0): MBConv(
#         6.0 k, 0.114% Params, 32.67 MMac, 7.963% MACs,
#         (block): Sequential(
#           6.0 k, 0.114% Params, 32.67 MMac, 7.963% MACs,
#           (0): Conv2dNormActivation(
#             1.73 k, 0.033% Params, 21.68 MMac, 5.284% MACs,
#             (0): Conv2d(1.54 k, 0.029% Params, 19.27 MMac, 4.697% MACs, 16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, 0.004% Params, 2.41 MMac, 0.587% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             1.06 k, 0.020% Params, 3.31 MMac, 0.807% MACs,
#             (0): Conv2d(864, 0.016% Params, 2.71 MMac, 0.661% MACs, 96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (1): BatchNorm2d(192, 0.004% Params, 602.11 KMac, 0.147% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             868, 0.016% Params, 301.92 KMac, 0.074% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 301.06 KMac, 0.073% MACs, output_size=1)
#             (fc1): Conv2d(388, 0.007% Params, 388.0 Mac, 0.000% MACs, 96, 4, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(480, 0.009% Params, 480.0 Mac, 0.000% MACs, 4, 96, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             2.35 k, 0.044% Params, 7.38 MMac, 1.798% MACs,
#             (0): Conv2d(2.3 k, 0.044% Params, 7.23 MMac, 1.761% MACs, 96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(48, 0.001% Params, 150.53 KMac, 0.037% MACs, 24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0125, mode=row)
#       )
#       (1): MBConv(
#         10.71 k, 0.203% Params, 28.15 MMac, 6.863% MACs,
#         (block): Sequential(
#           10.71 k, 0.203% Params, 28.15 MMac, 6.863% MACs,
#           (0): Conv2dNormActivation(
#             3.74 k, 0.071% Params, 11.74 MMac, 2.862% MACs,
#             (0): Conv2d(3.46 k, 0.065% Params, 10.84 MMac, 2.642% MACs, 24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(288, 0.005% Params, 903.17 KMac, 0.220% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             1.58 k, 0.030% Params, 4.97 MMac, 1.211% MACs,
#             (0): Conv2d(1.3 k, 0.025% Params, 4.06 MMac, 0.991% MACs, 144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(288, 0.005% Params, 903.17 KMac, 0.220% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             1.88 k, 0.036% Params, 453.46 KMac, 0.111% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 451.58 KMac, 0.110% MACs, output_size=1)
#             (fc1): Conv2d(870, 0.016% Params, 870.0 Mac, 0.000% MACs, 144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(1.01 k, 0.019% Params, 1.01 KMac, 0.000% MACs, 6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             3.5 k, 0.066% Params, 10.99 MMac, 2.679% MACs,
#             (0): Conv2d(3.46 k, 0.065% Params, 10.84 MMac, 2.642% MACs, 144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(48, 0.001% Params, 150.53 KMac, 0.037% MACs, 24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.025, mode=row)
#       )
#     )
#     (3): Sequential(
#       46.64 k, 0.882% Params, 40.25 MMac, 9.812% MACs,
#       (0): MBConv(
#         15.35 k, 0.290% Params, 19.48 MMac, 4.750% MACs,
#         (block): Sequential(
#           15.35 k, 0.290% Params, 19.48 MMac, 4.750% MACs,
#           (0): Conv2dNormActivation(
#             3.74 k, 0.071% Params, 11.74 MMac, 2.862% MACs,
#             (0): Conv2d(3.46 k, 0.065% Params, 10.84 MMac, 2.642% MACs, 24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(288, 0.005% Params, 903.17 KMac, 0.220% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             3.89 k, 0.074% Params, 3.05 MMac, 0.743% MACs,
#             (0): Conv2d(3.6 k, 0.068% Params, 2.82 MMac, 0.688% MACs, 144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#             (1): BatchNorm2d(288, 0.005% Params, 225.79 KMac, 0.055% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             1.88 k, 0.036% Params, 114.77 KMac, 0.028% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 112.9 KMac, 0.028% MACs, output_size=1)
#             (fc1): Conv2d(870, 0.016% Params, 870.0 Mac, 0.000% MACs, 144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(1.01 k, 0.019% Params, 1.01 KMac, 0.000% MACs, 6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             5.84 k, 0.110% Params, 4.58 MMac, 1.116% MACs,
#             (0): Conv2d(5.76 k, 0.109% Params, 4.52 MMac, 1.101% MACs, 144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, 0.002% Params, 62.72 KMac, 0.015% MACs, 40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.037500000000000006, mode=row)
#       )
#       (1): MBConv(
#         31.29 k, 0.592% Params, 20.77 MMac, 5.062% MACs,
#         (block): Sequential(
#           31.29 k, 0.592% Params, 20.77 MMac, 5.062% MACs,
#           (0): Conv2dNormActivation(
#             10.08 k, 0.191% Params, 7.9 MMac, 1.927% MACs,
#             (0): Conv2d(9.6 k, 0.182% Params, 7.53 MMac, 1.835% MACs, 40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, 0.009% Params, 376.32 KMac, 0.092% MACs, 240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             6.48 k, 0.123% Params, 5.08 MMac, 1.239% MACs,
#             (0): Conv2d(6.0 k, 0.113% Params, 4.7 MMac, 1.147% MACs, 240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#             (1): BatchNorm2d(480, 0.009% Params, 376.32 KMac, 0.092% MACs, 240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             5.05 k, 0.095% Params, 193.21 KMac, 0.047% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 188.16 KMac, 0.046% MACs, output_size=1)
#             (fc1): Conv2d(2.41 k, 0.046% Params, 2.41 KMac, 0.001% MACs, 240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(2.64 k, 0.050% Params, 2.64 KMac, 0.001% MACs, 10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             9.68 k, 0.183% Params, 7.59 MMac, 1.850% MACs,
#             (0): Conv2d(9.6 k, 0.182% Params, 7.53 MMac, 1.835% MACs, 240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, 0.002% Params, 62.72 KMac, 0.015% MACs, 40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05, mode=row)
#       )
#     )
#     (4): Sequential(
#       242.93 k, 4.594% Params, 45.11 MMac, 10.997% MACs,
#       (0): MBConv(
#         37.13 k, 0.702% Params, 12.27 MMac, 2.990% MACs,
#         (block): Sequential(
#           37.13 k, 0.702% Params, 12.27 MMac, 2.990% MACs,
#           (0): Conv2dNormActivation(
#             10.08 k, 0.191% Params, 7.9 MMac, 1.927% MACs,
#             (0): Conv2d(9.6 k, 0.182% Params, 7.53 MMac, 1.835% MACs, 40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, 0.009% Params, 376.32 KMac, 0.092% MACs, 240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             2.64 k, 0.050% Params, 517.44 KMac, 0.126% MACs,
#             (0): Conv2d(2.16 k, 0.041% Params, 423.36 KMac, 0.103% MACs, 240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#             (1): BatchNorm2d(480, 0.009% Params, 94.08 KMac, 0.023% MACs, 240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             5.05 k, 0.095% Params, 52.09 KMac, 0.013% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 47.04 KMac, 0.011% MACs, output_size=1)
#             (fc1): Conv2d(2.41 k, 0.046% Params, 2.41 KMac, 0.001% MACs, 240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(2.64 k, 0.050% Params, 2.64 KMac, 0.001% MACs, 10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             19.36 k, 0.366% Params, 3.79 MMac, 0.925% MACs,
#             (0): Conv2d(19.2 k, 0.363% Params, 3.76 MMac, 0.917% MACs, 240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, 0.003% Params, 31.36 KMac, 0.008% MACs, 80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0625, mode=row)
#       )
#       (1): MBConv(
#         102.9 k, 1.946% Params, 16.42 MMac, 4.003% MACs,
#         (block): Sequential(
#           102.9 k, 1.946% Params, 16.42 MMac, 4.003% MACs,
#           (0): Conv2dNormActivation(
#             39.36 k, 0.744% Params, 7.71 MMac, 1.881% MACs,
#             (0): Conv2d(38.4 k, 0.726% Params, 7.53 MMac, 1.835% MACs, 80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, 0.018% Params, 188.16 KMac, 0.046% MACs, 480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             5.28 k, 0.100% Params, 1.03 MMac, 0.252% MACs,
#             (0): Conv2d(4.32 k, 0.082% Params, 846.72 KMac, 0.206% MACs, 480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(960, 0.018% Params, 188.16 KMac, 0.046% MACs, 480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             19.7 k, 0.373% Params, 113.78 KMac, 0.028% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 94.08 KMac, 0.023% MACs, output_size=1)
#             (fc1): Conv2d(9.62 k, 0.182% Params, 9.62 KMac, 0.002% MACs, 480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10.08 k, 0.191% Params, 10.08 KMac, 0.002% MACs, 20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             38.56 k, 0.729% Params, 7.56 MMac, 1.842% MACs,
#             (0): Conv2d(38.4 k, 0.726% Params, 7.53 MMac, 1.835% MACs, 480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, 0.003% Params, 31.36 KMac, 0.008% MACs, 80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.07500000000000001, mode=row)
#       )
#       (2): MBConv(
#         102.9 k, 1.946% Params, 16.42 MMac, 4.003% MACs,
#         (block): Sequential(
#           102.9 k, 1.946% Params, 16.42 MMac, 4.003% MACs,
#           (0): Conv2dNormActivation(
#             39.36 k, 0.744% Params, 7.71 MMac, 1.881% MACs,
#             (0): Conv2d(38.4 k, 0.726% Params, 7.53 MMac, 1.835% MACs, 80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, 0.018% Params, 188.16 KMac, 0.046% MACs, 480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             5.28 k, 0.100% Params, 1.03 MMac, 0.252% MACs,
#             (0): Conv2d(4.32 k, 0.082% Params, 846.72 KMac, 0.206% MACs, 480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(960, 0.018% Params, 188.16 KMac, 0.046% MACs, 480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             19.7 k, 0.373% Params, 113.78 KMac, 0.028% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 94.08 KMac, 0.023% MACs, output_size=1)
#             (fc1): Conv2d(9.62 k, 0.182% Params, 9.62 KMac, 0.002% MACs, 480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10.08 k, 0.191% Params, 10.08 KMac, 0.002% MACs, 20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             38.56 k, 0.729% Params, 7.56 MMac, 1.842% MACs,
#             (0): Conv2d(38.4 k, 0.726% Params, 7.53 MMac, 1.835% MACs, 480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, 0.003% Params, 31.36 KMac, 0.008% MACs, 80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08750000000000001, mode=row)
#       )
#     )
#     (5): Sequential(
#       543.15 k, 10.270% Params, 88.02 MMac, 21.459% MACs,
#       (0): MBConv(
#         126.0 k, 2.383% Params, 20.95 MMac, 5.107% MACs,
#         (block): Sequential(
#           126.0 k, 2.383% Params, 20.95 MMac, 5.107% MACs,
#           (0): Conv2dNormActivation(
#             39.36 k, 0.744% Params, 7.71 MMac, 1.881% MACs,
#             (0): Conv2d(38.4 k, 0.726% Params, 7.53 MMac, 1.835% MACs, 80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, 0.018% Params, 188.16 KMac, 0.046% MACs, 480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             12.96 k, 0.245% Params, 2.54 MMac, 0.619% MACs,
#             (0): Conv2d(12.0 k, 0.227% Params, 2.35 MMac, 0.573% MACs, 480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#             (1): BatchNorm2d(960, 0.018% Params, 188.16 KMac, 0.046% MACs, 480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             19.7 k, 0.373% Params, 113.78 KMac, 0.028% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 94.08 KMac, 0.023% MACs, output_size=1)
#             (fc1): Conv2d(9.62 k, 0.182% Params, 9.62 KMac, 0.002% MACs, 480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10.08 k, 0.191% Params, 10.08 KMac, 0.002% MACs, 20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             53.98 k, 1.021% Params, 10.58 MMac, 2.579% MACs,
#             (0): Conv2d(53.76 k, 1.017% Params, 10.54 MMac, 2.569% MACs, 480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, 0.004% Params, 43.9 KMac, 0.011% MACs, 112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#       )
#       (1): MBConv(
#         208.57 k, 3.944% Params, 33.54 MMac, 8.176% MACs,
#         (block): Sequential(
#           208.57 k, 3.944% Params, 33.54 MMac, 8.176% MACs,
#           (0): Conv2dNormActivation(
#             76.61 k, 1.449% Params, 15.02 MMac, 3.660% MACs,
#             (0): Conv2d(75.26 k, 1.423% Params, 14.75 MMac, 3.596% MACs, 112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1.34 k, 0.025% Params, 263.42 KMac, 0.064% MACs, 672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             18.14 k, 0.343% Params, 3.56 MMac, 0.867% MACs,
#             (0): Conv2d(16.8 k, 0.318% Params, 3.29 MMac, 0.803% MACs, 672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(1.34 k, 0.025% Params, 263.42 KMac, 0.064% MACs, 672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             38.33 k, 0.725% Params, 170.04 KMac, 0.041% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 131.71 KMac, 0.032% MACs, output_size=1)
#             (fc1): Conv2d(18.84 k, 0.356% Params, 18.84 KMac, 0.005% MACs, 672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(19.49 k, 0.368% Params, 19.49 KMac, 0.005% MACs, 28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             75.49 k, 1.427% Params, 14.8 MMac, 3.607% MACs,
#             (0): Conv2d(75.26 k, 1.423% Params, 14.75 MMac, 3.596% MACs, 672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, 0.004% Params, 43.9 KMac, 0.011% MACs, 112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1125, mode=row)
#       )
#       (2): MBConv(
#         208.57 k, 3.944% Params, 33.54 MMac, 8.176% MACs,
#         (block): Sequential(
#           208.57 k, 3.944% Params, 33.54 MMac, 8.176% MACs,
#           (0): Conv2dNormActivation(
#             76.61 k, 1.449% Params, 15.02 MMac, 3.660% MACs,
#             (0): Conv2d(75.26 k, 1.423% Params, 14.75 MMac, 3.596% MACs, 112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1.34 k, 0.025% Params, 263.42 KMac, 0.064% MACs, 672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             18.14 k, 0.343% Params, 3.56 MMac, 0.867% MACs,
#             (0): Conv2d(16.8 k, 0.318% Params, 3.29 MMac, 0.803% MACs, 672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(1.34 k, 0.025% Params, 263.42 KMac, 0.064% MACs, 672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             38.33 k, 0.725% Params, 170.04 KMac, 0.041% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 131.71 KMac, 0.032% MACs, output_size=1)
#             (fc1): Conv2d(18.84 k, 0.356% Params, 18.84 KMac, 0.005% MACs, 672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(19.49 k, 0.368% Params, 19.49 KMac, 0.005% MACs, 28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             75.49 k, 1.427% Params, 14.8 MMac, 3.607% MACs,
#             (0): Conv2d(75.26 k, 1.423% Params, 14.75 MMac, 3.596% MACs, 672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(224, 0.004% Params, 43.9 KMac, 0.011% MACs, 112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.125, mode=row)
#       )
#     )
#     (6): Sequential(
#       2.03 M, 38.316% Params, 92.82 MMac, 22.627% MACs,
#       (0): MBConv(
#         262.49 k, 4.963% Params, 22.32 MMac, 5.440% MACs,
#         (block): Sequential(
#           262.49 k, 4.963% Params, 22.32 MMac, 5.440% MACs,
#           (0): Conv2dNormActivation(
#             76.61 k, 1.449% Params, 15.02 MMac, 3.660% MACs,
#             (0): Conv2d(75.26 k, 1.423% Params, 14.75 MMac, 3.596% MACs, 112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1.34 k, 0.025% Params, 263.42 KMac, 0.064% MACs, 672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             18.14 k, 0.343% Params, 889.06 KMac, 0.217% MACs,
#             (0): Conv2d(16.8 k, 0.318% Params, 823.2 KMac, 0.201% MACs, 672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(1.34 k, 0.025% Params, 65.86 KMac, 0.016% MACs, 672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             38.33 k, 0.725% Params, 71.26 KMac, 0.017% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 32.93 KMac, 0.008% MACs, output_size=1)
#             (fc1): Conv2d(18.84 k, 0.356% Params, 18.84 KMac, 0.005% MACs, 672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(19.49 k, 0.368% Params, 19.49 KMac, 0.005% MACs, 28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             129.41 k, 2.447% Params, 6.34 MMac, 1.546% MACs,
#             (0): Conv2d(129.02 k, 2.440% Params, 6.32 MMac, 1.541% MACs, 672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, 0.007% Params, 18.82 KMac, 0.005% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1375, mode=row)
#       )
#       (1): MBConv(
#         587.95 k, 11.117% Params, 23.5 MMac, 5.729% MACs,
#         (block): Sequential(
#           587.95 k, 11.117% Params, 23.5 MMac, 5.729% MACs,
#           (0): Conv2dNormActivation(
#             223.49 k, 4.226% Params, 10.95 MMac, 2.670% MACs,
#             (0): Conv2d(221.18 k, 4.182% Params, 10.84 MMac, 2.642% MACs, 192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2.3 k, 0.044% Params, 112.9 KMac, 0.028% MACs, 1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             31.1 k, 0.588% Params, 1.52 MMac, 0.372% MACs,
#             (0): Conv2d(28.8 k, 0.545% Params, 1.41 MMac, 0.344% MACs, 1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(2.3 k, 0.044% Params, 112.9 KMac, 0.028% MACs, 1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             111.79 k, 2.114% Params, 168.24 KMac, 0.041% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 56.45 KMac, 0.014% MACs, output_size=1)
#             (fc1): Conv2d(55.34 k, 1.046% Params, 55.34 KMac, 0.013% MACs, 1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56.45 k, 1.067% Params, 56.45 KMac, 0.014% MACs, 48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             221.57 k, 4.190% Params, 10.86 MMac, 2.647% MACs,
#             (0): Conv2d(221.18 k, 4.182% Params, 10.84 MMac, 2.642% MACs, 1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, 0.007% Params, 18.82 KMac, 0.005% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.15000000000000002, mode=row)
#       )
#       (2): MBConv(
#         587.95 k, 11.117% Params, 23.5 MMac, 5.729% MACs,
#         (block): Sequential(
#           587.95 k, 11.117% Params, 23.5 MMac, 5.729% MACs,
#           (0): Conv2dNormActivation(
#             223.49 k, 4.226% Params, 10.95 MMac, 2.670% MACs,
#             (0): Conv2d(221.18 k, 4.182% Params, 10.84 MMac, 2.642% MACs, 192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2.3 k, 0.044% Params, 112.9 KMac, 0.028% MACs, 1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             31.1 k, 0.588% Params, 1.52 MMac, 0.372% MACs,
#             (0): Conv2d(28.8 k, 0.545% Params, 1.41 MMac, 0.344% MACs, 1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(2.3 k, 0.044% Params, 112.9 KMac, 0.028% MACs, 1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             111.79 k, 2.114% Params, 168.24 KMac, 0.041% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 56.45 KMac, 0.014% MACs, output_size=1)
#             (fc1): Conv2d(55.34 k, 1.046% Params, 55.34 KMac, 0.013% MACs, 1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56.45 k, 1.067% Params, 56.45 KMac, 0.014% MACs, 48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             221.57 k, 4.190% Params, 10.86 MMac, 2.647% MACs,
#             (0): Conv2d(221.18 k, 4.182% Params, 10.84 MMac, 2.642% MACs, 1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, 0.007% Params, 18.82 KMac, 0.005% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1625, mode=row)
#       )
#       (3): MBConv(
#         587.95 k, 11.117% Params, 23.5 MMac, 5.729% MACs,
#         (block): Sequential(
#           587.95 k, 11.117% Params, 23.5 MMac, 5.729% MACs,
#           (0): Conv2dNormActivation(
#             223.49 k, 4.226% Params, 10.95 MMac, 2.670% MACs,
#             (0): Conv2d(221.18 k, 4.182% Params, 10.84 MMac, 2.642% MACs, 192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2.3 k, 0.044% Params, 112.9 KMac, 0.028% MACs, 1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             31.1 k, 0.588% Params, 1.52 MMac, 0.372% MACs,
#             (0): Conv2d(28.8 k, 0.545% Params, 1.41 MMac, 0.344% MACs, 1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(2.3 k, 0.044% Params, 112.9 KMac, 0.028% MACs, 1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             111.79 k, 2.114% Params, 168.24 KMac, 0.041% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 56.45 KMac, 0.014% MACs, output_size=1)
#             (fc1): Conv2d(55.34 k, 1.046% Params, 55.34 KMac, 0.013% MACs, 1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56.45 k, 1.067% Params, 56.45 KMac, 0.014% MACs, 48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             221.57 k, 4.190% Params, 10.86 MMac, 2.647% MACs,
#             (0): Conv2d(221.18 k, 4.182% Params, 10.84 MMac, 2.642% MACs, 1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, 0.007% Params, 18.82 KMac, 0.005% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17500000000000002, mode=row)
#       )
#     )
#     (7): Sequential(
#       717.23 k, 13.562% Params, 29.83 MMac, 7.273% MACs,
#       (0): MBConv(
#         717.23 k, 13.562% Params, 29.83 MMac, 7.273% MACs,
#         (block): Sequential(
#           717.23 k, 13.562% Params, 29.83 MMac, 7.273% MACs,
#           (0): Conv2dNormActivation(
#             223.49 k, 4.226% Params, 10.95 MMac, 2.670% MACs,
#             (0): Conv2d(221.18 k, 4.182% Params, 10.84 MMac, 2.642% MACs, 192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2.3 k, 0.044% Params, 112.9 KMac, 0.028% MACs, 1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             12.67 k, 0.240% Params, 620.93 KMac, 0.151% MACs,
#             (0): Conv2d(10.37 k, 0.196% Params, 508.03 KMac, 0.124% MACs, 1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#             (1): BatchNorm2d(2.3 k, 0.044% Params, 112.9 KMac, 0.028% MACs, 1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             111.79 k, 2.114% Params, 168.24 KMac, 0.041% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 56.45 KMac, 0.014% MACs, output_size=1)
#             (fc1): Conv2d(55.34 k, 1.046% Params, 55.34 KMac, 0.013% MACs, 1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(56.45 k, 1.067% Params, 56.45 KMac, 0.014% MACs, 48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             369.28 k, 6.983% Params, 18.09 MMac, 4.411% MACs,
#             (0): Conv2d(368.64 k, 6.971% Params, 18.06 MMac, 4.404% MACs, 1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(640, 0.012% Params, 31.36 KMac, 0.008% MACs, 320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1875, mode=row)
#       )
#     )
#     (8): Conv2dNormActivation(
#       412.16 k, 7.793% Params, 20.2 MMac, 4.923% MACs,
#       (0): Conv2d(409.6 k, 7.745% Params, 20.07 MMac, 4.893% MACs, 320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(2.56 k, 0.048% Params, 125.44 KMac, 0.031% MACs, 1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 62.72 KMac, 0.015% MACs, output_size=1)
#   (classifier): Sequential(
#     1.28 M, 24.222% Params, 1.28 MMac, 0.312% MACs,
#     (0): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.2, inplace=True)
#     (1): Linear(1.28 M, 24.222% Params, 1.28 MMac, 0.312% MACs, in_features=1280, out_features=1000, bias=True)
#   )
# )
# FLOPs: 410.2 MMac, Parameters: 5.29 M

# %%
from ptflops import get_model_complexity_info

# Example with ResNet-50
model = models.inception_v3(pretrained=True)

# Input dimensions
macs, params = get_model_complexity_info(model, (3, 299, 299), as_strings=True, print_per_layer_stat=True)
print(f"FLOPs: {macs}, Parameters: {params}")
# Out:
# C:\Users\mruba\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Inception3(
#   27.16 M, 100.000% Params, 5.73 GMac, 99.756% MACs,
#   (Conv2d_1a_3x3): BasicConv2d(
#     928, 0.003% Params, 20.6 MMac, 0.358% MACs,
#     (conv): Conv2d(864, 0.003% Params, 19.18 MMac, 0.334% MACs, 3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(64, 0.000% Params, 1.42 MMac, 0.025% MACs, 32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2a_3x3): BasicConv2d(
#     9.28 k, 0.034% Params, 200.53 MMac, 3.489% MACs,
#     (conv): Conv2d(9.22 k, 0.034% Params, 199.15 MMac, 3.465% MACs, 32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, 0.000% Params, 1.38 MMac, 0.024% MACs, 32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2b_3x3): BasicConv2d(
#     18.56 k, 0.068% Params, 401.06 MMac, 6.978% MACs,
#     (conv): Conv2d(18.43 k, 0.068% Params, 398.3 MMac, 6.930% MACs, 32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(128, 0.000% Params, 2.77 MMac, 0.048% MACs, 64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(0, 0.000% Params, 1.38 MMac, 0.024% MACs, kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Conv2d_3b_1x1): BasicConv2d(
#     5.28 k, 0.019% Params, 28.14 MMac, 0.490% MACs,
#     (conv): Conv2d(5.12 k, 0.019% Params, 27.28 MMac, 0.475% MACs, 64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(160, 0.001% Params, 852.64 KMac, 0.015% MACs, 80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_4a_3x3): BasicConv2d(
#     138.62 k, 0.510% Params, 698.8 MMac, 12.158% MACs,
#     (conv): Conv2d(138.24 k, 0.509% Params, 696.87 MMac, 12.124% MACs, 80, 192, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(384, 0.001% Params, 1.94 MMac, 0.034% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(0, 0.000% Params, 967.87 KMac, 0.017% MACs, kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Mixed_5b): InceptionA(
#     255.9 k, 0.942% Params, 313.48 MMac, 5.454% MACs,
#     (branch1x1): BasicConv2d(
#       12.42 k, 0.046% Params, 15.21 MMac, 0.265% MACs,
#       (conv): Conv2d(12.29 k, 0.045% Params, 15.05 MMac, 0.262% MACs, 192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, 0.000% Params, 156.8 KMac, 0.003% MACs, 64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       9.31 k, 0.034% Params, 11.41 MMac, 0.198% MACs,
#       (conv): Conv2d(9.22 k, 0.034% Params, 11.29 MMac, 0.196% MACs, 192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, 0.000% Params, 117.6 KMac, 0.002% MACs, 48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       76.93 k, 0.283% Params, 94.24 MMac, 1.640% MACs,
#       (conv): Conv2d(76.8 k, 0.283% Params, 94.08 MMac, 1.637% MACs, 48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(128, 0.000% Params, 156.8 KMac, 0.003% MACs, 64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       12.42 k, 0.046% Params, 15.21 MMac, 0.265% MACs,
#       (conv): Conv2d(12.29 k, 0.045% Params, 15.05 MMac, 0.262% MACs, 192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, 0.000% Params, 156.8 KMac, 0.003% MACs, 64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       55.49 k, 0.204% Params, 67.97 MMac, 1.183% MACs,
#       (conv): Conv2d(55.3 k, 0.204% Params, 67.74 MMac, 1.179% MACs, 64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, 0.001% Params, 235.2 KMac, 0.004% MACs, 96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       83.14 k, 0.306% Params, 101.84 MMac, 1.772% MACs,
#       (conv): Conv2d(82.94 k, 0.305% Params, 101.61 MMac, 1.768% MACs, 96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, 0.001% Params, 235.2 KMac, 0.004% MACs, 96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       6.21 k, 0.023% Params, 7.6 MMac, 0.132% MACs,
#       (conv): Conv2d(6.14 k, 0.023% Params, 7.53 MMac, 0.131% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, 0.000% Params, 78.4 KMac, 0.001% MACs, 32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5c): InceptionA(
#     277.47 k, 1.022% Params, 339.9 MMac, 5.914% MACs,
#     (branch1x1): BasicConv2d(
#       16.51 k, 0.061% Params, 20.23 MMac, 0.352% MACs,
#       (conv): Conv2d(16.38 k, 0.060% Params, 20.07 MMac, 0.349% MACs, 256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, 0.000% Params, 156.8 KMac, 0.003% MACs, 64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       12.38 k, 0.046% Params, 15.17 MMac, 0.264% MACs,
#       (conv): Conv2d(12.29 k, 0.045% Params, 15.05 MMac, 0.262% MACs, 256, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, 0.000% Params, 117.6 KMac, 0.002% MACs, 48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       76.93 k, 0.283% Params, 94.24 MMac, 1.640% MACs,
#       (conv): Conv2d(76.8 k, 0.283% Params, 94.08 MMac, 1.637% MACs, 48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(128, 0.000% Params, 156.8 KMac, 0.003% MACs, 64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       16.51 k, 0.061% Params, 20.23 MMac, 0.352% MACs,
#       (conv): Conv2d(16.38 k, 0.060% Params, 20.07 MMac, 0.349% MACs, 256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, 0.000% Params, 156.8 KMac, 0.003% MACs, 64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       55.49 k, 0.204% Params, 67.97 MMac, 1.183% MACs,
#       (conv): Conv2d(55.3 k, 0.204% Params, 67.74 MMac, 1.179% MACs, 64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, 0.001% Params, 235.2 KMac, 0.004% MACs, 96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       83.14 k, 0.306% Params, 101.84 MMac, 1.772% MACs,
#       (conv): Conv2d(82.94 k, 0.305% Params, 101.61 MMac, 1.768% MACs, 96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, 0.001% Params, 235.2 KMac, 0.004% MACs, 96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       16.51 k, 0.061% Params, 20.23 MMac, 0.352% MACs,
#       (conv): Conv2d(16.38 k, 0.060% Params, 20.07 MMac, 0.349% MACs, 256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, 0.000% Params, 156.8 KMac, 0.003% MACs, 64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5d): InceptionA(
#     285.15 k, 1.050% Params, 349.31 MMac, 6.077% MACs,
#     (branch1x1): BasicConv2d(
#       18.56 k, 0.068% Params, 22.74 MMac, 0.396% MACs,
#       (conv): Conv2d(18.43 k, 0.068% Params, 22.58 MMac, 0.393% MACs, 288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, 0.000% Params, 156.8 KMac, 0.003% MACs, 64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       13.92 k, 0.051% Params, 17.05 MMac, 0.297% MACs,
#       (conv): Conv2d(13.82 k, 0.051% Params, 16.93 MMac, 0.295% MACs, 288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, 0.000% Params, 117.6 KMac, 0.002% MACs, 48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       76.93 k, 0.283% Params, 94.24 MMac, 1.640% MACs,
#       (conv): Conv2d(76.8 k, 0.283% Params, 94.08 MMac, 1.637% MACs, 48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(128, 0.000% Params, 156.8 KMac, 0.003% MACs, 64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       18.56 k, 0.068% Params, 22.74 MMac, 0.396% MACs,
#       (conv): Conv2d(18.43 k, 0.068% Params, 22.58 MMac, 0.393% MACs, 288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, 0.000% Params, 156.8 KMac, 0.003% MACs, 64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       55.49 k, 0.204% Params, 67.97 MMac, 1.183% MACs,
#       (conv): Conv2d(55.3 k, 0.204% Params, 67.74 MMac, 1.179% MACs, 64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, 0.001% Params, 235.2 KMac, 0.004% MACs, 96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       83.14 k, 0.306% Params, 101.84 MMac, 1.772% MACs,
#       (conv): Conv2d(82.94 k, 0.305% Params, 101.61 MMac, 1.768% MACs, 96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, 0.001% Params, 235.2 KMac, 0.004% MACs, 96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       18.56 k, 0.068% Params, 22.74 MMac, 0.396% MACs,
#       (conv): Conv2d(18.43 k, 0.068% Params, 22.58 MMac, 0.393% MACs, 288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, 0.000% Params, 156.8 KMac, 0.003% MACs, 64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6a): InceptionB(
#     1.15 M, 4.246% Params, 402.61 MMac, 7.005% MACs,
#     (branch3x3): BasicConv2d(
#       996.1 k, 3.667% Params, 287.87 MMac, 5.009% MACs,
#       (conv): Conv2d(995.33 k, 3.665% Params, 287.65 MMac, 5.005% MACs, 288, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(768, 0.003% Params, 221.95 KMac, 0.004% MACs, 384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       18.56 k, 0.068% Params, 22.74 MMac, 0.396% MACs,
#       (conv): Conv2d(18.43 k, 0.068% Params, 22.58 MMac, 0.393% MACs, 288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, 0.000% Params, 156.8 KMac, 0.003% MACs, 64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       55.49 k, 0.204% Params, 67.97 MMac, 1.183% MACs,
#       (conv): Conv2d(55.3 k, 0.204% Params, 67.74 MMac, 1.179% MACs, 64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, 0.001% Params, 235.2 KMac, 0.004% MACs, 96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       83.14 k, 0.306% Params, 24.03 MMac, 0.418% MACs,
#       (conv): Conv2d(82.94 k, 0.305% Params, 23.97 MMac, 0.417% MACs, 96, 96, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(192, 0.001% Params, 55.49 KMac, 0.001% MACs, 96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6b): InceptionC(
#     1.3 M, 4.777% Params, 374.95 MMac, 6.524% MACs,
#     (branch1x1): BasicConv2d(
#       147.84 k, 0.544% Params, 42.73 MMac, 0.743% MACs,
#       (conv): Conv2d(147.46 k, 0.543% Params, 42.61 MMac, 0.741% MACs, 768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, 0.001% Params, 110.98 KMac, 0.002% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       98.56 k, 0.363% Params, 28.48 MMac, 0.496% MACs,
#       (conv): Conv2d(98.3 k, 0.362% Params, 28.41 MMac, 0.494% MACs, 768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, 0.001% Params, 73.98 KMac, 0.001% MACs, 128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       114.94 k, 0.423% Params, 33.22 MMac, 0.578% MACs,
#       (conv): Conv2d(114.69 k, 0.422% Params, 33.14 MMac, 0.577% MACs, 128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(256, 0.001% Params, 73.98 KMac, 0.001% MACs, 128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       172.42 k, 0.635% Params, 49.83 MMac, 0.867% MACs,
#       (conv): Conv2d(172.03 k, 0.633% Params, 49.72 MMac, 0.865% MACs, 128, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(384, 0.001% Params, 110.98 KMac, 0.002% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       98.56 k, 0.363% Params, 28.48 MMac, 0.496% MACs,
#       (conv): Conv2d(98.3 k, 0.362% Params, 28.41 MMac, 0.494% MACs, 768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, 0.001% Params, 73.98 KMac, 0.001% MACs, 128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       114.94 k, 0.423% Params, 33.22 MMac, 0.578% MACs,
#       (conv): Conv2d(114.69 k, 0.422% Params, 33.14 MMac, 0.577% MACs, 128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(256, 0.001% Params, 73.98 KMac, 0.001% MACs, 128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       114.94 k, 0.423% Params, 33.22 MMac, 0.578% MACs,
#       (conv): Conv2d(114.69 k, 0.422% Params, 33.14 MMac, 0.577% MACs, 128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(256, 0.001% Params, 73.98 KMac, 0.001% MACs, 128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       114.94 k, 0.423% Params, 33.22 MMac, 0.578% MACs,
#       (conv): Conv2d(114.69 k, 0.422% Params, 33.14 MMac, 0.577% MACs, 128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(256, 0.001% Params, 73.98 KMac, 0.001% MACs, 128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       172.42 k, 0.635% Params, 49.83 MMac, 0.867% MACs,
#       (conv): Conv2d(172.03 k, 0.633% Params, 49.72 MMac, 0.865% MACs, 128, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(384, 0.001% Params, 110.98 KMac, 0.002% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       147.84 k, 0.544% Params, 42.73 MMac, 0.743% MACs,
#       (conv): Conv2d(147.46 k, 0.543% Params, 42.61 MMac, 0.741% MACs, 768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, 0.001% Params, 110.98 KMac, 0.002% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6c): InceptionC(
#     1.69 M, 6.226% Params, 488.7 MMac, 8.503% MACs,
#     (branch1x1): BasicConv2d(
#       147.84 k, 0.544% Params, 42.73 MMac, 0.743% MACs,
#       (conv): Conv2d(147.46 k, 0.543% Params, 42.61 MMac, 0.741% MACs, 768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, 0.001% Params, 110.98 KMac, 0.002% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       123.2 k, 0.454% Params, 35.6 MMac, 0.619% MACs,
#       (conv): Conv2d(122.88 k, 0.452% Params, 35.51 MMac, 0.618% MACs, 768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, 0.001% Params, 92.48 KMac, 0.002% MACs, 160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       179.52 k, 0.661% Params, 51.88 MMac, 0.903% MACs,
#       (conv): Conv2d(179.2 k, 0.660% Params, 51.79 MMac, 0.901% MACs, 160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(320, 0.001% Params, 92.48 KMac, 0.002% MACs, 160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       215.42 k, 0.793% Params, 62.26 MMac, 1.083% MACs,
#       (conv): Conv2d(215.04 k, 0.792% Params, 62.15 MMac, 1.081% MACs, 160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(384, 0.001% Params, 110.98 KMac, 0.002% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       123.2 k, 0.454% Params, 35.6 MMac, 0.619% MACs,
#       (conv): Conv2d(122.88 k, 0.452% Params, 35.51 MMac, 0.618% MACs, 768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, 0.001% Params, 92.48 KMac, 0.002% MACs, 160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       179.52 k, 0.661% Params, 51.88 MMac, 0.903% MACs,
#       (conv): Conv2d(179.2 k, 0.660% Params, 51.79 MMac, 0.901% MACs, 160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(320, 0.001% Params, 92.48 KMac, 0.002% MACs, 160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       179.52 k, 0.661% Params, 51.88 MMac, 0.903% MACs,
#       (conv): Conv2d(179.2 k, 0.660% Params, 51.79 MMac, 0.901% MACs, 160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(320, 0.001% Params, 92.48 KMac, 0.002% MACs, 160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       179.52 k, 0.661% Params, 51.88 MMac, 0.903% MACs,
#       (conv): Conv2d(179.2 k, 0.660% Params, 51.79 MMac, 0.901% MACs, 160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(320, 0.001% Params, 92.48 KMac, 0.002% MACs, 160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       215.42 k, 0.793% Params, 62.26 MMac, 1.083% MACs,
#       (conv): Conv2d(215.04 k, 0.792% Params, 62.15 MMac, 1.081% MACs, 160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(384, 0.001% Params, 110.98 KMac, 0.002% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       147.84 k, 0.544% Params, 42.73 MMac, 0.743% MACs,
#       (conv): Conv2d(147.46 k, 0.543% Params, 42.61 MMac, 0.741% MACs, 768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, 0.001% Params, 110.98 KMac, 0.002% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6d): InceptionC(
#     1.69 M, 6.226% Params, 488.7 MMac, 8.503% MACs,
#     (branch1x1): BasicConv2d(
#       147.84 k, 0.544% Params, 42.73 MMac, 0.743% MACs,
#       (conv): Conv2d(147.46 k, 0.543% Params, 42.61 MMac, 0.741% MACs, 768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, 0.001% Params, 110.98 KMac, 0.002% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       123.2 k, 0.454% Params, 35.6 MMac, 0.619% MACs,
#       (conv): Conv2d(122.88 k, 0.452% Params, 35.51 MMac, 0.618% MACs, 768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, 0.001% Params, 92.48 KMac, 0.002% MACs, 160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       179.52 k, 0.661% Params, 51.88 MMac, 0.903% MACs,
#       (conv): Conv2d(179.2 k, 0.660% Params, 51.79 MMac, 0.901% MACs, 160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(320, 0.001% Params, 92.48 KMac, 0.002% MACs, 160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       215.42 k, 0.793% Params, 62.26 MMac, 1.083% MACs,
#       (conv): Conv2d(215.04 k, 0.792% Params, 62.15 MMac, 1.081% MACs, 160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(384, 0.001% Params, 110.98 KMac, 0.002% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       123.2 k, 0.454% Params, 35.6 MMac, 0.619% MACs,
#       (conv): Conv2d(122.88 k, 0.452% Params, 35.51 MMac, 0.618% MACs, 768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, 0.001% Params, 92.48 KMac, 0.002% MACs, 160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       179.52 k, 0.661% Params, 51.88 MMac, 0.903% MACs,
#       (conv): Conv2d(179.2 k, 0.660% Params, 51.79 MMac, 0.901% MACs, 160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(320, 0.001% Params, 92.48 KMac, 0.002% MACs, 160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       179.52 k, 0.661% Params, 51.88 MMac, 0.903% MACs,
#       (conv): Conv2d(179.2 k, 0.660% Params, 51.79 MMac, 0.901% MACs, 160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(320, 0.001% Params, 92.48 KMac, 0.002% MACs, 160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       179.52 k, 0.661% Params, 51.88 MMac, 0.903% MACs,
#       (conv): Conv2d(179.2 k, 0.660% Params, 51.79 MMac, 0.901% MACs, 160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(320, 0.001% Params, 92.48 KMac, 0.002% MACs, 160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       215.42 k, 0.793% Params, 62.26 MMac, 1.083% MACs,
#       (conv): Conv2d(215.04 k, 0.792% Params, 62.15 MMac, 1.081% MACs, 160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(384, 0.001% Params, 110.98 KMac, 0.002% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       147.84 k, 0.544% Params, 42.73 MMac, 0.743% MACs,
#       (conv): Conv2d(147.46 k, 0.543% Params, 42.61 MMac, 0.741% MACs, 768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, 0.001% Params, 110.98 KMac, 0.002% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6e): InceptionC(
#     2.14 M, 7.886% Params, 619.02 MMac, 10.770% MACs,
#     (branch1x1): BasicConv2d(
#       147.84 k, 0.544% Params, 42.73 MMac, 0.743% MACs,
#       (conv): Conv2d(147.46 k, 0.543% Params, 42.61 MMac, 0.741% MACs, 768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, 0.001% Params, 110.98 KMac, 0.002% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       147.84 k, 0.544% Params, 42.73 MMac, 0.743% MACs,
#       (conv): Conv2d(147.46 k, 0.543% Params, 42.61 MMac, 0.741% MACs, 768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, 0.001% Params, 110.98 KMac, 0.002% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       258.43 k, 0.951% Params, 74.69 MMac, 1.299% MACs,
#       (conv): Conv2d(258.05 k, 0.950% Params, 74.58 MMac, 1.297% MACs, 192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(384, 0.001% Params, 110.98 KMac, 0.002% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       258.43 k, 0.951% Params, 74.69 MMac, 1.299% MACs,
#       (conv): Conv2d(258.05 k, 0.950% Params, 74.58 MMac, 1.297% MACs, 192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(384, 0.001% Params, 110.98 KMac, 0.002% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       147.84 k, 0.544% Params, 42.73 MMac, 0.743% MACs,
#       (conv): Conv2d(147.46 k, 0.543% Params, 42.61 MMac, 0.741% MACs, 768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, 0.001% Params, 110.98 KMac, 0.002% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       258.43 k, 0.951% Params, 74.69 MMac, 1.299% MACs,
#       (conv): Conv2d(258.05 k, 0.950% Params, 74.58 MMac, 1.297% MACs, 192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(384, 0.001% Params, 110.98 KMac, 0.002% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       258.43 k, 0.951% Params, 74.69 MMac, 1.299% MACs,
#       (conv): Conv2d(258.05 k, 0.950% Params, 74.58 MMac, 1.297% MACs, 192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(384, 0.001% Params, 110.98 KMac, 0.002% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       258.43 k, 0.951% Params, 74.69 MMac, 1.299% MACs,
#       (conv): Conv2d(258.05 k, 0.950% Params, 74.58 MMac, 1.297% MACs, 192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(384, 0.001% Params, 110.98 KMac, 0.002% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       258.43 k, 0.951% Params, 74.69 MMac, 1.299% MACs,
#       (conv): Conv2d(258.05 k, 0.950% Params, 74.58 MMac, 1.297% MACs, 192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(384, 0.001% Params, 110.98 KMac, 0.002% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       147.84 k, 0.544% Params, 42.73 MMac, 0.743% MACs,
#       (conv): Conv2d(147.46 k, 0.543% Params, 42.61 MMac, 0.741% MACs, 768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, 0.001% Params, 110.98 KMac, 0.002% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (AuxLogits): InceptionAux(
#     3.33 M, 12.248% Params, 0.0 Mac, 0.000% MACs,
#     (conv0): BasicConv2d(
#       98.56 k, 0.363% Params, 0.0 Mac, 0.000% MACs,
#       (conv): Conv2d(98.3 k, 0.362% Params, 0.0 Mac, 0.000% MACs, 768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, 0.001% Params, 0.0 Mac, 0.000% MACs, 128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv1): BasicConv2d(
#       2.46 M, 9.054% Params, 0.0 Mac, 0.000% MACs,
#       (conv): Conv2d(2.46 M, 9.048% Params, 0.0 Mac, 0.000% MACs, 128, 768, kernel_size=(5, 5), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(1.54 k, 0.006% Params, 0.0 Mac, 0.000% MACs, 768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (fc): Linear(769.0 k, 2.831% Params, 0.0 Mac, 0.000% MACs, in_features=768, out_features=1000, bias=True)
#   )
#   (Mixed_7a): InceptionD(
#     1.7 M, 6.253% Params, 291.51 MMac, 5.072% MACs,
#     (branch3x3_1): BasicConv2d(
#       147.84 k, 0.544% Params, 42.73 MMac, 0.743% MACs,
#       (conv): Conv2d(147.46 k, 0.543% Params, 42.61 MMac, 0.741% MACs, 768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, 0.001% Params, 110.98 KMac, 0.002% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2): BasicConv2d(
#       553.6 k, 2.038% Params, 35.43 MMac, 0.616% MACs,
#       (conv): Conv2d(552.96 k, 2.036% Params, 35.39 MMac, 0.616% MACs, 192, 320, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(640, 0.002% Params, 40.96 KMac, 0.001% MACs, 320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_1): BasicConv2d(
#       147.84 k, 0.544% Params, 42.73 MMac, 0.743% MACs,
#       (conv): Conv2d(147.46 k, 0.543% Params, 42.61 MMac, 0.741% MACs, 768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, 0.001% Params, 110.98 KMac, 0.002% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_2): BasicConv2d(
#       258.43 k, 0.951% Params, 74.69 MMac, 1.299% MACs,
#       (conv): Conv2d(258.05 k, 0.950% Params, 74.58 MMac, 1.297% MACs, 192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(384, 0.001% Params, 110.98 KMac, 0.002% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_3): BasicConv2d(
#       258.43 k, 0.951% Params, 74.69 MMac, 1.299% MACs,
#       (conv): Conv2d(258.05 k, 0.950% Params, 74.58 MMac, 1.297% MACs, 192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(384, 0.001% Params, 110.98 KMac, 0.002% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_4): BasicConv2d(
#       332.16 k, 1.223% Params, 21.26 MMac, 0.370% MACs,
#       (conv): Conv2d(331.78 k, 1.222% Params, 21.23 MMac, 0.369% MACs, 192, 192, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(384, 0.001% Params, 24.58 KMac, 0.000% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7b): InceptionE(
#     5.04 M, 18.573% Params, 322.85 MMac, 5.617% MACs,
#     (branch1x1): BasicConv2d(
#       410.24 k, 1.510% Params, 26.26 MMac, 0.457% MACs,
#       (conv): Conv2d(409.6 k, 1.508% Params, 26.21 MMac, 0.456% MACs, 1280, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(640, 0.002% Params, 40.96 KMac, 0.001% MACs, 320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       492.29 k, 1.812% Params, 31.51 MMac, 0.548% MACs,
#       (conv): Conv2d(491.52 k, 1.810% Params, 31.46 MMac, 0.547% MACs, 1280, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(768, 0.003% Params, 49.15 KMac, 0.001% MACs, 384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       443.14 k, 1.631% Params, 28.36 MMac, 0.493% MACs,
#       (conv): Conv2d(442.37 k, 1.629% Params, 28.31 MMac, 0.493% MACs, 384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(768, 0.003% Params, 49.15 KMac, 0.001% MACs, 384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       443.14 k, 1.631% Params, 28.36 MMac, 0.493% MACs,
#       (conv): Conv2d(442.37 k, 1.629% Params, 28.31 MMac, 0.493% MACs, 384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(768, 0.003% Params, 49.15 KMac, 0.001% MACs, 384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       574.34 k, 2.115% Params, 36.76 MMac, 0.640% MACs,
#       (conv): Conv2d(573.44 k, 2.111% Params, 36.7 MMac, 0.639% MACs, 1280, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(896, 0.003% Params, 57.34 KMac, 0.001% MACs, 448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       1.55 M, 5.703% Params, 99.14 MMac, 1.725% MACs,
#       (conv): Conv2d(1.55 M, 5.700% Params, 99.09 MMac, 1.724% MACs, 448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(768, 0.003% Params, 49.15 KMac, 0.001% MACs, 384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       443.14 k, 1.631% Params, 28.36 MMac, 0.493% MACs,
#       (conv): Conv2d(442.37 k, 1.629% Params, 28.31 MMac, 0.493% MACs, 384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(768, 0.003% Params, 49.15 KMac, 0.001% MACs, 384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       443.14 k, 1.631% Params, 28.36 MMac, 0.493% MACs,
#       (conv): Conv2d(442.37 k, 1.629% Params, 28.31 MMac, 0.493% MACs, 384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(768, 0.003% Params, 49.15 KMac, 0.001% MACs, 384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       246.14 k, 0.906% Params, 15.75 MMac, 0.274% MACs,
#       (conv): Conv2d(245.76 k, 0.905% Params, 15.73 MMac, 0.274% MACs, 1280, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, 0.001% Params, 24.58 KMac, 0.000% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7c): InceptionE(
#     6.08 M, 22.373% Params, 388.92 MMac, 6.766% MACs,
#     (branch1x1): BasicConv2d(
#       656.0 k, 2.415% Params, 41.98 MMac, 0.730% MACs,
#       (conv): Conv2d(655.36 k, 2.413% Params, 41.94 MMac, 0.730% MACs, 2048, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(640, 0.002% Params, 40.96 KMac, 0.001% MACs, 320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       787.2 k, 2.898% Params, 50.38 MMac, 0.877% MACs,
#       (conv): Conv2d(786.43 k, 2.895% Params, 50.33 MMac, 0.876% MACs, 2048, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(768, 0.003% Params, 49.15 KMac, 0.001% MACs, 384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       443.14 k, 1.631% Params, 28.36 MMac, 0.493% MACs,
#       (conv): Conv2d(442.37 k, 1.629% Params, 28.31 MMac, 0.493% MACs, 384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(768, 0.003% Params, 49.15 KMac, 0.001% MACs, 384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       443.14 k, 1.631% Params, 28.36 MMac, 0.493% MACs,
#       (conv): Conv2d(442.37 k, 1.629% Params, 28.31 MMac, 0.493% MACs, 384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(768, 0.003% Params, 49.15 KMac, 0.001% MACs, 384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       918.4 k, 3.381% Params, 58.78 MMac, 1.023% MACs,
#       (conv): Conv2d(917.5 k, 3.378% Params, 58.72 MMac, 1.022% MACs, 2048, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(896, 0.003% Params, 57.34 KMac, 0.001% MACs, 448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       1.55 M, 5.703% Params, 99.14 MMac, 1.725% MACs,
#       (conv): Conv2d(1.55 M, 5.700% Params, 99.09 MMac, 1.724% MACs, 448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(768, 0.003% Params, 49.15 KMac, 0.001% MACs, 384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       443.14 k, 1.631% Params, 28.36 MMac, 0.493% MACs,
#       (conv): Conv2d(442.37 k, 1.629% Params, 28.31 MMac, 0.493% MACs, 384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(768, 0.003% Params, 49.15 KMac, 0.001% MACs, 384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       443.14 k, 1.631% Params, 28.36 MMac, 0.493% MACs,
#       (conv): Conv2d(442.37 k, 1.629% Params, 28.31 MMac, 0.493% MACs, 384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(768, 0.003% Params, 49.15 KMac, 0.001% MACs, 384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       393.6 k, 1.449% Params, 25.19 MMac, 0.438% MACs,
#       (conv): Conv2d(393.22 k, 1.448% Params, 25.17 MMac, 0.438% MACs, 2048, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, 0.001% Params, 24.58 KMac, 0.000% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 131.07 KMac, 0.002% MACs, output_size=(1, 1))
#   (dropout): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.5, inplace=False)
#   (fc): Linear(2.05 M, 7.544% Params, 2.05 MMac, 0.036% MACs, in_features=2048, out_features=1000, bias=True)
# )
# FLOPs: 5.75 GMac, Parameters: 27.16 M

# %%
import torchvision.models as models
from fvcore.nn import FlopCountAnalysis

model_list = [models.mobilenet_v2, models.densenet121, models.squeezenet1_0, models.alexnet, models.resnext50_32x4d]

for model_fn in model_list:
    model = model_fn(pretrained=True)
    model.eval()
    input_tensor = torch.randn(1, 3, 224, 224)
    
    flops = FlopCountAnalysis(model, input_tensor)
    print(f"{model_fn.__name__}: FLOPs = {flops.total()}")
# Out:
# Unsupported operator aten::hardtanh_ encountered 35 time(s)
# Unsupported operator aten::add encountered 10 time(s)
# C:\Users\mruba\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\mruba\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# mobilenet_v2: FLOPs = 314193216
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to C:\Users\mruba/.cache\torch\hub\checkpoints\densenet121-a639ec97.pth
# 100%|█████████████████████████████████████████████████████████████████████████████| 30.8M/30.8M [00:03<00:00, 9.06MB/s]
# Unsupported operator aten::max_pool2d encountered 1 time(s)
# Unsupported operator aten::avg_pool2d encountered 3 time(s)
# C:\Users\mruba\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\mruba\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=SqueezeNet1_0_Weights.IMAGENET1K_V1`. You can also use `weights=SqueezeNet1_0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/squeezenet1_0-b66bff10.pth" to C:\Users\mruba/.cache\torch\hub\checkpoints\squeezenet1_0-b66bff10.pth
# densenet121: FLOPs = 2865546752
# 100%|█████████████████████████████████████████████████████████████████████████████| 4.78M/4.78M [00:00<00:00, 14.7MB/s]
# Unsupported operator aten::max_pool2d encountered 3 time(s)
# C:\Users\mruba\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\mruba\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# squeezenet1_0: FLOPs = 819093576
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to C:\Users\mruba/.cache\torch\hub\checkpoints\alexnet-owt-7be5be79.pth
# 100%|███████████████████████████████████████████████████████████████████████████████| 233M/233M [00:36<00:00, 6.62MB/s]
# Unsupported operator aten::max_pool2d encountered 3 time(s)
# C:\Users\mruba\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\mruba\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNeXt50_32X4D_Weights.IMAGENET1K_V1`. You can also use `weights=ResNeXt50_32X4D_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# alexnet: FLOPs = 714197696
# Downloading: "https://download.pytorch.org/models/resnext50_32x4d-7cdf4587.pth" to C:\Users\mruba/.cache\torch\hub\checkpoints\resnext50_32x4d-7cdf4587.pth
# 100%|█████████████████████████████████████████████████████████████████████████████| 95.8M/95.8M [00:16<00:00, 6.20MB/s]
# Unsupported operator aten::max_pool2d encountered 1 time(s)
# Unsupported operator aten::add_ encountered 16 time(s)
# resnext50_32x4d: FLOPs = 4259381248

# %%
from ptflops import get_model_complexity_info

model = models.mobilenet_v2(pretrained=True)

macs, params = get_model_complexity_info(model, (3, 224, 224), as_strings=True, print_per_layer_stat=True)
print(f"FLOPs: {macs}, Parameters: {params}")
# Out:
# C:\Users\mruba\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\mruba\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V2_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# MobileNetV2(
#   3.5 M, 100.000% Params, 320.24 MMac, 99.980% MACs,
#   (features): Sequential(
#     2.22 M, 63.451% Params, 318.96 MMac, 99.580% MACs,
#     (0): Conv2dNormActivation(
#       928, 0.026% Params, 12.04 MMac, 3.760% MACs,
#       (0): Conv2d(864, 0.025% Params, 10.84 MMac, 3.384% MACs, 3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, 0.002% Params, 802.82 KMac, 0.251% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(0, 0.000% Params, 401.41 KMac, 0.125% MACs, inplace=True)
#     )
#     (1): InvertedResidual(
#       896, 0.026% Params, 11.64 MMac, 3.634% MACs,
#       (conv): Sequential(
#         896, 0.026% Params, 11.64 MMac, 3.634% MACs,
#         (0): Conv2dNormActivation(
#           352, 0.010% Params, 4.82 MMac, 1.504% MACs,
#           (0): Conv2d(288, 0.008% Params, 3.61 MMac, 1.128% MACs, 32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (1): BatchNorm2d(64, 0.002% Params, 802.82 KMac, 0.251% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 401.41 KMac, 0.125% MACs, inplace=True)
#         )
#         (1): Conv2d(512, 0.015% Params, 6.42 MMac, 2.005% MACs, 32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(32, 0.001% Params, 401.41 KMac, 0.125% MACs, 16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): InvertedResidual(
#       5.14 k, 0.147% Params, 33.87 MMac, 10.574% MACs,
#       (conv): Sequential(
#         5.14 k, 0.147% Params, 33.87 MMac, 10.574% MACs,
#         (0): Conv2dNormActivation(
#           1.73 k, 0.049% Params, 22.88 MMac, 7.143% MACs,
#           (0): Conv2d(1.54 k, 0.044% Params, 19.27 MMac, 6.015% MACs, 16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, 0.005% Params, 2.41 MMac, 0.752% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 1.2 MMac, 0.376% MACs, inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           1.06 k, 0.030% Params, 3.61 MMac, 1.128% MACs,
#           (0): Conv2d(864, 0.025% Params, 2.71 MMac, 0.846% MACs, 96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#           (1): BatchNorm2d(192, 0.005% Params, 602.11 KMac, 0.188% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 301.06 KMac, 0.094% MACs, inplace=True)
#         )
#         (2): Conv2d(2.3 k, 0.066% Params, 7.23 MMac, 2.256% MACs, 96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(48, 0.001% Params, 150.53 KMac, 0.047% MACs, 24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): InvertedResidual(
#       8.83 k, 0.252% Params, 28.6 MMac, 8.929% MACs,
#       (conv): Sequential(
#         8.83 k, 0.252% Params, 28.6 MMac, 8.929% MACs,
#         (0): Conv2dNormActivation(
#           3.74 k, 0.107% Params, 12.19 MMac, 3.807% MACs,
#           (0): Conv2d(3.46 k, 0.099% Params, 10.84 MMac, 3.384% MACs, 24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(288, 0.008% Params, 903.17 KMac, 0.282% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 451.58 KMac, 0.141% MACs, inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           1.58 k, 0.045% Params, 5.42 MMac, 1.692% MACs,
#           (0): Conv2d(1.3 k, 0.037% Params, 4.06 MMac, 1.269% MACs, 144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(288, 0.008% Params, 903.17 KMac, 0.282% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 451.58 KMac, 0.141% MACs, inplace=True)
#         )
#         (2): Conv2d(3.46 k, 0.099% Params, 10.84 MMac, 3.384% MACs, 144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(48, 0.001% Params, 150.53 KMac, 0.047% MACs, 24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): InvertedResidual(
#       10.0 k, 0.285% Params, 17.21 MMac, 5.373% MACs,
#       (conv): Sequential(
#         10.0 k, 0.285% Params, 17.21 MMac, 5.373% MACs,
#         (0): Conv2dNormActivation(
#           3.74 k, 0.107% Params, 12.19 MMac, 3.807% MACs,
#           (0): Conv2d(3.46 k, 0.099% Params, 10.84 MMac, 3.384% MACs, 24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(288, 0.008% Params, 903.17 KMac, 0.282% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 451.58 KMac, 0.141% MACs, inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           1.58 k, 0.045% Params, 1.35 MMac, 0.423% MACs,
#           (0): Conv2d(1.3 k, 0.037% Params, 1.02 MMac, 0.317% MACs, 144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(288, 0.008% Params, 225.79 KMac, 0.070% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 112.9 KMac, 0.035% MACs, inplace=True)
#         )
#         (2): Conv2d(4.61 k, 0.131% Params, 3.61 MMac, 1.128% MACs, 144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, 0.002% Params, 50.18 KMac, 0.016% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): InvertedResidual(
#       14.85 k, 0.424% Params, 11.94 MMac, 3.728% MACs,
#       (conv): Sequential(
#         14.85 k, 0.424% Params, 11.94 MMac, 3.728% MACs,
#         (0): Conv2dNormActivation(
#           6.53 k, 0.186% Params, 5.27 MMac, 1.645% MACs,
#           (0): Conv2d(6.14 k, 0.175% Params, 4.82 MMac, 1.504% MACs, 32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, 0.011% Params, 301.06 KMac, 0.094% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 150.53 KMac, 0.047% MACs, inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           2.11 k, 0.060% Params, 1.81 MMac, 0.564% MACs,
#           (0): Conv2d(1.73 k, 0.049% Params, 1.35 MMac, 0.423% MACs, 192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(384, 0.011% Params, 301.06 KMac, 0.094% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 150.53 KMac, 0.047% MACs, inplace=True)
#         )
#         (2): Conv2d(6.14 k, 0.175% Params, 4.82 MMac, 1.504% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, 0.002% Params, 50.18 KMac, 0.016% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): InvertedResidual(
#       14.85 k, 0.424% Params, 11.94 MMac, 3.728% MACs,
#       (conv): Sequential(
#         14.85 k, 0.424% Params, 11.94 MMac, 3.728% MACs,
#         (0): Conv2dNormActivation(
#           6.53 k, 0.186% Params, 5.27 MMac, 1.645% MACs,
#           (0): Conv2d(6.14 k, 0.175% Params, 4.82 MMac, 1.504% MACs, 32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, 0.011% Params, 301.06 KMac, 0.094% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 150.53 KMac, 0.047% MACs, inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           2.11 k, 0.060% Params, 1.81 MMac, 0.564% MACs,
#           (0): Conv2d(1.73 k, 0.049% Params, 1.35 MMac, 0.423% MACs, 192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(384, 0.011% Params, 301.06 KMac, 0.094% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 150.53 KMac, 0.047% MACs, inplace=True)
#         )
#         (2): Conv2d(6.14 k, 0.175% Params, 4.82 MMac, 1.504% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, 0.002% Params, 50.18 KMac, 0.016% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): InvertedResidual(
#       21.06 k, 0.601% Params, 8.15 MMac, 2.546% MACs,
#       (conv): Sequential(
#         21.06 k, 0.601% Params, 8.15 MMac, 2.546% MACs,
#         (0): Conv2dNormActivation(
#           6.53 k, 0.186% Params, 5.27 MMac, 1.645% MACs,
#           (0): Conv2d(6.14 k, 0.175% Params, 4.82 MMac, 1.504% MACs, 32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, 0.011% Params, 301.06 KMac, 0.094% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 150.53 KMac, 0.047% MACs, inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           2.11 k, 0.060% Params, 451.58 KMac, 0.141% MACs,
#           (0): Conv2d(1.73 k, 0.049% Params, 338.69 KMac, 0.106% MACs, 192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(384, 0.011% Params, 75.26 KMac, 0.023% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 37.63 KMac, 0.012% MACs, inplace=True)
#         )
#         (2): Conv2d(12.29 k, 0.351% Params, 2.41 MMac, 0.752% MACs, 192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, 0.004% Params, 25.09 KMac, 0.008% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): InvertedResidual(
#       54.27 k, 1.548% Params, 10.79 MMac, 3.368% MACs,
#       (conv): Sequential(
#         54.27 k, 1.548% Params, 10.79 MMac, 3.368% MACs,
#         (0): Conv2dNormActivation(
#           25.34 k, 0.723% Params, 5.04 MMac, 1.574% MACs,
#           (0): Conv2d(24.58 k, 0.701% Params, 4.82 MMac, 1.504% MACs, 64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(768, 0.022% Params, 150.53 KMac, 0.047% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 75.26 KMac, 0.023% MACs, inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           4.22 k, 0.121% Params, 903.17 KMac, 0.282% MACs,
#           (0): Conv2d(3.46 k, 0.099% Params, 677.38 KMac, 0.211% MACs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(768, 0.022% Params, 150.53 KMac, 0.047% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 75.26 KMac, 0.023% MACs, inplace=True)
#         )
#         (2): Conv2d(24.58 k, 0.701% Params, 4.82 MMac, 1.504% MACs, 384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, 0.004% Params, 25.09 KMac, 0.008% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (9): InvertedResidual(
#       54.27 k, 1.548% Params, 10.79 MMac, 3.368% MACs,
#       (conv): Sequential(
#         54.27 k, 1.548% Params, 10.79 MMac, 3.368% MACs,
#         (0): Conv2dNormActivation(
#           25.34 k, 0.723% Params, 5.04 MMac, 1.574% MACs,
#           (0): Conv2d(24.58 k, 0.701% Params, 4.82 MMac, 1.504% MACs, 64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(768, 0.022% Params, 150.53 KMac, 0.047% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 75.26 KMac, 0.023% MACs, inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           4.22 k, 0.121% Params, 903.17 KMac, 0.282% MACs,
#           (0): Conv2d(3.46 k, 0.099% Params, 677.38 KMac, 0.211% MACs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(768, 0.022% Params, 150.53 KMac, 0.047% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 75.26 KMac, 0.023% MACs, inplace=True)
#         )
#         (2): Conv2d(24.58 k, 0.701% Params, 4.82 MMac, 1.504% MACs, 384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, 0.004% Params, 25.09 KMac, 0.008% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): InvertedResidual(
#       54.27 k, 1.548% Params, 10.79 MMac, 3.368% MACs,
#       (conv): Sequential(
#         54.27 k, 1.548% Params, 10.79 MMac, 3.368% MACs,
#         (0): Conv2dNormActivation(
#           25.34 k, 0.723% Params, 5.04 MMac, 1.574% MACs,
#           (0): Conv2d(24.58 k, 0.701% Params, 4.82 MMac, 1.504% MACs, 64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(768, 0.022% Params, 150.53 KMac, 0.047% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 75.26 KMac, 0.023% MACs, inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           4.22 k, 0.121% Params, 903.17 KMac, 0.282% MACs,
#           (0): Conv2d(3.46 k, 0.099% Params, 677.38 KMac, 0.211% MACs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(768, 0.022% Params, 150.53 KMac, 0.047% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 75.26 KMac, 0.023% MACs, inplace=True)
#         )
#         (2): Conv2d(24.58 k, 0.701% Params, 4.82 MMac, 1.504% MACs, 384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, 0.004% Params, 25.09 KMac, 0.008% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): InvertedResidual(
#       66.62 k, 1.901% Params, 13.21 MMac, 4.124% MACs,
#       (conv): Sequential(
#         66.62 k, 1.901% Params, 13.21 MMac, 4.124% MACs,
#         (0): Conv2dNormActivation(
#           25.34 k, 0.723% Params, 5.04 MMac, 1.574% MACs,
#           (0): Conv2d(24.58 k, 0.701% Params, 4.82 MMac, 1.504% MACs, 64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(768, 0.022% Params, 150.53 KMac, 0.047% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 75.26 KMac, 0.023% MACs, inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           4.22 k, 0.121% Params, 903.17 KMac, 0.282% MACs,
#           (0): Conv2d(3.46 k, 0.099% Params, 677.38 KMac, 0.211% MACs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(768, 0.022% Params, 150.53 KMac, 0.047% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 75.26 KMac, 0.023% MACs, inplace=True)
#         )
#         (2): Conv2d(36.86 k, 1.052% Params, 7.23 MMac, 2.256% MACs, 384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(192, 0.005% Params, 37.63 KMac, 0.012% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): InvertedResidual(
#       118.27 k, 3.375% Params, 23.41 MMac, 7.308% MACs,
#       (conv): Sequential(
#         118.27 k, 3.375% Params, 23.41 MMac, 7.308% MACs,
#         (0): Conv2dNormActivation(
#           56.45 k, 1.611% Params, 11.18 MMac, 3.489% MACs,
#           (0): Conv2d(55.3 k, 1.578% Params, 10.84 MMac, 3.384% MACs, 96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1.15 k, 0.033% Params, 225.79 KMac, 0.070% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 112.9 KMac, 0.035% MACs, inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           6.34 k, 0.181% Params, 1.35 MMac, 0.423% MACs,
#           (0): Conv2d(5.18 k, 0.148% Params, 1.02 MMac, 0.317% MACs, 576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(1.15 k, 0.033% Params, 225.79 KMac, 0.070% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 112.9 KMac, 0.035% MACs, inplace=True)
#         )
#         (2): Conv2d(55.3 k, 1.578% Params, 10.84 MMac, 3.384% MACs, 576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(192, 0.005% Params, 37.63 KMac, 0.012% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): InvertedResidual(
#       118.27 k, 3.375% Params, 23.41 MMac, 7.308% MACs,
#       (conv): Sequential(
#         118.27 k, 3.375% Params, 23.41 MMac, 7.308% MACs,
#         (0): Conv2dNormActivation(
#           56.45 k, 1.611% Params, 11.18 MMac, 3.489% MACs,
#           (0): Conv2d(55.3 k, 1.578% Params, 10.84 MMac, 3.384% MACs, 96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1.15 k, 0.033% Params, 225.79 KMac, 0.070% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 112.9 KMac, 0.035% MACs, inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           6.34 k, 0.181% Params, 1.35 MMac, 0.423% MACs,
#           (0): Conv2d(5.18 k, 0.148% Params, 1.02 MMac, 0.317% MACs, 576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(1.15 k, 0.033% Params, 225.79 KMac, 0.070% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 112.9 KMac, 0.035% MACs, inplace=True)
#         )
#         (2): Conv2d(55.3 k, 1.578% Params, 10.84 MMac, 3.384% MACs, 576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(192, 0.005% Params, 37.63 KMac, 0.012% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): InvertedResidual(
#       155.26 k, 4.430% Params, 16.05 MMac, 5.010% MACs,
#       (conv): Sequential(
#         155.26 k, 4.430% Params, 16.05 MMac, 5.010% MACs,
#         (0): Conv2dNormActivation(
#           56.45 k, 1.611% Params, 11.18 MMac, 3.489% MACs,
#           (0): Conv2d(55.3 k, 1.578% Params, 10.84 MMac, 3.384% MACs, 96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1.15 k, 0.033% Params, 225.79 KMac, 0.070% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 112.9 KMac, 0.035% MACs, inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           6.34 k, 0.181% Params, 338.69 KMac, 0.106% MACs,
#           (0): Conv2d(5.18 k, 0.148% Params, 254.02 KMac, 0.079% MACs, 576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(1.15 k, 0.033% Params, 56.45 KMac, 0.018% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 28.22 KMac, 0.009% MACs, inplace=True)
#         )
#         (2): Conv2d(92.16 k, 2.629% Params, 4.52 MMac, 1.410% MACs, 576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(320, 0.009% Params, 15.68 KMac, 0.005% MACs, 160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): InvertedResidual(
#       320.0 k, 9.130% Params, 15.77 MMac, 4.925% MACs,
#       (conv): Sequential(
#         320.0 k, 9.130% Params, 15.77 MMac, 4.925% MACs,
#         (0): Conv2dNormActivation(
#           155.52 k, 4.437% Params, 7.67 MMac, 2.394% MACs,
#           (0): Conv2d(153.6 k, 4.382% Params, 7.53 MMac, 2.350% MACs, 160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1.92 k, 0.055% Params, 94.08 KMac, 0.029% MACs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 47.04 KMac, 0.015% MACs, inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           10.56 k, 0.301% Params, 564.48 KMac, 0.176% MACs,
#           (0): Conv2d(8.64 k, 0.247% Params, 423.36 KMac, 0.132% MACs, 960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(1.92 k, 0.055% Params, 94.08 KMac, 0.029% MACs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 47.04 KMac, 0.015% MACs, inplace=True)
#         )
#         (2): Conv2d(153.6 k, 4.382% Params, 7.53 MMac, 2.350% MACs, 960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(320, 0.009% Params, 15.68 KMac, 0.005% MACs, 160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (16): InvertedResidual(
#       320.0 k, 9.130% Params, 15.77 MMac, 4.925% MACs,
#       (conv): Sequential(
#         320.0 k, 9.130% Params, 15.77 MMac, 4.925% MACs,
#         (0): Conv2dNormActivation(
#           155.52 k, 4.437% Params, 7.67 MMac, 2.394% MACs,
#           (0): Conv2d(153.6 k, 4.382% Params, 7.53 MMac, 2.350% MACs, 160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1.92 k, 0.055% Params, 94.08 KMac, 0.029% MACs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 47.04 KMac, 0.015% MACs, inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           10.56 k, 0.301% Params, 564.48 KMac, 0.176% MACs,
#           (0): Conv2d(8.64 k, 0.247% Params, 423.36 KMac, 0.132% MACs, 960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(1.92 k, 0.055% Params, 94.08 KMac, 0.029% MACs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 47.04 KMac, 0.015% MACs, inplace=True)
#         )
#         (2): Conv2d(153.6 k, 4.382% Params, 7.53 MMac, 2.350% MACs, 960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(320, 0.009% Params, 15.68 KMac, 0.005% MACs, 160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (17): InvertedResidual(
#       473.92 k, 13.522% Params, 23.32 MMac, 7.279% MACs,
#       (conv): Sequential(
#         473.92 k, 13.522% Params, 23.32 MMac, 7.279% MACs,
#         (0): Conv2dNormActivation(
#           155.52 k, 4.437% Params, 7.67 MMac, 2.394% MACs,
#           (0): Conv2d(153.6 k, 4.382% Params, 7.53 MMac, 2.350% MACs, 160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1.92 k, 0.055% Params, 94.08 KMac, 0.029% MACs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 47.04 KMac, 0.015% MACs, inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           10.56 k, 0.301% Params, 564.48 KMac, 0.176% MACs,
#           (0): Conv2d(8.64 k, 0.247% Params, 423.36 KMac, 0.132% MACs, 960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(1.92 k, 0.055% Params, 94.08 KMac, 0.029% MACs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 47.04 KMac, 0.015% MACs, inplace=True)
#         )
#         (2): Conv2d(307.2 k, 8.765% Params, 15.05 MMac, 4.700% MACs, 960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(640, 0.018% Params, 31.36 KMac, 0.010% MACs, 320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (18): Conv2dNormActivation(
#       412.16 k, 11.760% Params, 20.26 MMac, 6.325% MACs,
#       (0): Conv2d(409.6 k, 11.687% Params, 20.07 MMac, 6.266% MACs, 320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(2.56 k, 0.073% Params, 125.44 KMac, 0.039% MACs, 1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(0, 0.000% Params, 62.72 KMac, 0.020% MACs, inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     1.28 M, 36.549% Params, 1.28 MMac, 0.400% MACs,
#     (0): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.2, inplace=False)
#     (1): Linear(1.28 M, 36.549% Params, 1.28 MMac, 0.400% MACs, in_features=1280, out_features=1000, bias=True)
#   )
# )
# FLOPs: 320.3 MMac, Parameters: 3.5 M

# %%
from ptflops import get_model_complexity_info

model = models.densenet121(pretrained=True)

macs, params = get_model_complexity_info(model, (3, 224, 224), as_strings=True, print_per_layer_stat=True)
print(f"FLOPs: {macs}, Parameters: {params}")
# Out:
# C:\Users\mruba\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# DenseNet(
#   7.98 M, 100.000% Params, 2.88 GMac, 99.406% MACs,
#   (features): Sequential(
#     6.95 M, 87.154% Params, 2.88 GMac, 99.371% MACs,
#     (conv0): Conv2d(9.41 k, 0.118% Params, 118.01 MMac, 4.070% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (norm0): BatchNorm2d(128, 0.002% Params, 1.61 MMac, 0.055% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(0, 0.000% Params, 802.82 KMac, 0.028% MACs, inplace=True)
#     (pool0): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.028% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (denseblock1): _DenseBlock(
#       335.04 k, 4.199% Params, 1.06 GMac, 36.409% MACs,
#       (denselayer1): _DenseLayer(
#         45.44 k, 0.570% Params, 143.1 MMac, 4.935% MACs,
#         (norm1): BatchNorm2d(128, 0.002% Params, 401.41 KMac, 0.014% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 200.7 KMac, 0.007% MACs, inplace=True)
#         (conv1): Conv2d(8.19 k, 0.103% Params, 25.69 MMac, 0.886% MACs, 64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 802.82 KMac, 0.028% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 401.41 KMac, 0.014% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 115.61 MMac, 3.987% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         49.6 k, 0.622% Params, 156.25 MMac, 5.388% MACs,
#         (norm1): BatchNorm2d(192, 0.002% Params, 602.11 KMac, 0.021% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 301.06 KMac, 0.010% MACs, inplace=True)
#         (conv1): Conv2d(12.29 k, 0.154% Params, 38.54 MMac, 1.329% MACs, 96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 802.82 KMac, 0.028% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 401.41 KMac, 0.014% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 115.61 MMac, 3.987% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         53.76 k, 0.674% Params, 169.39 MMac, 5.841% MACs,
#         (norm1): BatchNorm2d(256, 0.003% Params, 802.82 KMac, 0.028% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 401.41 KMac, 0.014% MACs, inplace=True)
#         (conv1): Conv2d(16.38 k, 0.205% Params, 51.38 MMac, 1.772% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 802.82 KMac, 0.028% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 401.41 KMac, 0.014% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 115.61 MMac, 3.987% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         57.92 k, 0.726% Params, 182.54 MMac, 6.295% MACs,
#         (norm1): BatchNorm2d(320, 0.004% Params, 1.0 MMac, 0.035% MACs, 160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 501.76 KMac, 0.017% MACs, inplace=True)
#         (conv1): Conv2d(20.48 k, 0.257% Params, 64.23 MMac, 2.215% MACs, 160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 802.82 KMac, 0.028% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 401.41 KMac, 0.014% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 115.61 MMac, 3.987% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         62.08 k, 0.778% Params, 195.69 MMac, 6.748% MACs,
#         (norm1): BatchNorm2d(384, 0.005% Params, 1.2 MMac, 0.042% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 602.11 KMac, 0.021% MACs, inplace=True)
#         (conv1): Conv2d(24.58 k, 0.308% Params, 77.07 MMac, 2.658% MACs, 192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 802.82 KMac, 0.028% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 401.41 KMac, 0.014% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 115.61 MMac, 3.987% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         66.24 k, 0.830% Params, 208.83 MMac, 7.202% MACs,
#         (norm1): BatchNorm2d(448, 0.006% Params, 1.4 MMac, 0.048% MACs, 224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 702.46 KMac, 0.024% MACs, inplace=True)
#         (conv1): Conv2d(28.67 k, 0.359% Params, 89.92 MMac, 3.101% MACs, 224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 802.82 KMac, 0.028% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 401.41 KMac, 0.014% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 115.61 MMac, 3.987% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition1): _Transition(
#       33.28 k, 0.417% Params, 105.57 MMac, 3.641% MACs,
#       (norm): BatchNorm2d(512, 0.006% Params, 1.61 MMac, 0.055% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 802.82 KMac, 0.028% MACs, inplace=True)
#       (conv): Conv2d(32.77 k, 0.411% Params, 102.76 MMac, 3.544% MACs, 256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(0, 0.000% Params, 401.41 KMac, 0.014% MACs, kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock2): _DenseBlock(
#       919.68 k, 11.526% Params, 725.09 MMac, 25.005% MACs,
#       (denselayer1): _DenseLayer(
#         53.76 k, 0.674% Params, 42.35 MMac, 1.460% MACs,
#         (norm1): BatchNorm2d(256, 0.003% Params, 200.7 KMac, 0.007% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 100.35 KMac, 0.003% MACs, inplace=True)
#         (conv1): Conv2d(16.38 k, 0.205% Params, 12.85 MMac, 0.443% MACs, 128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 200.7 KMac, 0.007% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 100.35 KMac, 0.003% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 28.9 MMac, 0.997% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         57.92 k, 0.726% Params, 45.64 MMac, 1.574% MACs,
#         (norm1): BatchNorm2d(320, 0.004% Params, 250.88 KMac, 0.009% MACs, 160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 125.44 KMac, 0.004% MACs, inplace=True)
#         (conv1): Conv2d(20.48 k, 0.257% Params, 16.06 MMac, 0.554% MACs, 160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 200.7 KMac, 0.007% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 100.35 KMac, 0.003% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 28.9 MMac, 0.997% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         62.08 k, 0.778% Params, 48.92 MMac, 1.687% MACs,
#         (norm1): BatchNorm2d(384, 0.005% Params, 301.06 KMac, 0.010% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 150.53 KMac, 0.005% MACs, inplace=True)
#         (conv1): Conv2d(24.58 k, 0.308% Params, 19.27 MMac, 0.664% MACs, 192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 200.7 KMac, 0.007% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 100.35 KMac, 0.003% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 28.9 MMac, 0.997% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         66.24 k, 0.830% Params, 52.21 MMac, 1.800% MACs,
#         (norm1): BatchNorm2d(448, 0.006% Params, 351.23 KMac, 0.012% MACs, 224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 175.62 KMac, 0.006% MACs, inplace=True)
#         (conv1): Conv2d(28.67 k, 0.359% Params, 22.48 MMac, 0.775% MACs, 224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 200.7 KMac, 0.007% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 100.35 KMac, 0.003% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 28.9 MMac, 0.997% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         70.4 k, 0.882% Params, 55.49 MMac, 1.914% MACs,
#         (norm1): BatchNorm2d(512, 0.006% Params, 401.41 KMac, 0.014% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 200.7 KMac, 0.007% MACs, inplace=True)
#         (conv1): Conv2d(32.77 k, 0.411% Params, 25.69 MMac, 0.886% MACs, 256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 200.7 KMac, 0.007% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 100.35 KMac, 0.003% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 28.9 MMac, 0.997% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         74.56 k, 0.934% Params, 58.78 MMac, 2.027% MACs,
#         (norm1): BatchNorm2d(576, 0.007% Params, 451.58 KMac, 0.016% MACs, 288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 225.79 KMac, 0.008% MACs, inplace=True)
#         (conv1): Conv2d(36.86 k, 0.462% Params, 28.9 MMac, 0.997% MACs, 288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 200.7 KMac, 0.007% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 100.35 KMac, 0.003% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 28.9 MMac, 0.997% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         78.72 k, 0.987% Params, 62.07 MMac, 2.140% MACs,
#         (norm1): BatchNorm2d(640, 0.008% Params, 501.76 KMac, 0.017% MACs, 320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 250.88 KMac, 0.009% MACs, inplace=True)
#         (conv1): Conv2d(40.96 k, 0.513% Params, 32.11 MMac, 1.107% MACs, 320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 200.7 KMac, 0.007% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 100.35 KMac, 0.003% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 28.9 MMac, 0.997% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         82.88 k, 1.039% Params, 65.35 MMac, 2.254% MACs,
#         (norm1): BatchNorm2d(704, 0.009% Params, 551.94 KMac, 0.019% MACs, 352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 275.97 KMac, 0.010% MACs, inplace=True)
#         (conv1): Conv2d(45.06 k, 0.565% Params, 35.32 MMac, 1.218% MACs, 352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 200.7 KMac, 0.007% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 100.35 KMac, 0.003% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 28.9 MMac, 0.997% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         87.04 k, 1.091% Params, 68.64 MMac, 2.367% MACs,
#         (norm1): BatchNorm2d(768, 0.010% Params, 602.11 KMac, 0.021% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 301.06 KMac, 0.010% MACs, inplace=True)
#         (conv1): Conv2d(49.15 k, 0.616% Params, 38.54 MMac, 1.329% MACs, 384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 200.7 KMac, 0.007% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 100.35 KMac, 0.003% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 28.9 MMac, 0.997% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         91.2 k, 1.143% Params, 71.93 MMac, 2.480% MACs,
#         (norm1): BatchNorm2d(832, 0.010% Params, 652.29 KMac, 0.022% MACs, 416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 326.14 KMac, 0.011% MACs, inplace=True)
#         (conv1): Conv2d(53.25 k, 0.667% Params, 41.75 MMac, 1.440% MACs, 416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 200.7 KMac, 0.007% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 100.35 KMac, 0.003% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 28.9 MMac, 0.997% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         95.36 k, 1.195% Params, 75.21 MMac, 2.594% MACs,
#         (norm1): BatchNorm2d(896, 0.011% Params, 702.46 KMac, 0.024% MACs, 448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 351.23 KMac, 0.012% MACs, inplace=True)
#         (conv1): Conv2d(57.34 k, 0.719% Params, 44.96 MMac, 1.550% MACs, 448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 200.7 KMac, 0.007% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 100.35 KMac, 0.003% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 28.9 MMac, 0.997% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         99.52 k, 1.247% Params, 78.5 MMac, 2.707% MACs,
#         (norm1): BatchNorm2d(960, 0.012% Params, 752.64 KMac, 0.026% MACs, 480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 376.32 KMac, 0.013% MACs, inplace=True)
#         (conv1): Conv2d(61.44 k, 0.770% Params, 48.17 MMac, 1.661% MACs, 480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 200.7 KMac, 0.007% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 100.35 KMac, 0.003% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 28.9 MMac, 0.997% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition2): _Transition(
#       132.1 k, 1.656% Params, 104.17 MMac, 3.592% MACs,
#       (norm): BatchNorm2d(1.02 k, 0.013% Params, 802.82 KMac, 0.028% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 401.41 KMac, 0.014% MACs, inplace=True)
#       (conv): Conv2d(131.07 k, 1.643% Params, 102.76 MMac, 3.544% MACs, 512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(0, 0.000% Params, 200.7 KMac, 0.007% MACs, kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock3): _DenseBlock(
#       2.84 M, 35.566% Params, 559.74 MMac, 19.302% MACs,
#       (denselayer1): _DenseLayer(
#         70.4 k, 0.882% Params, 13.87 MMac, 0.478% MACs,
#         (norm1): BatchNorm2d(512, 0.006% Params, 100.35 KMac, 0.003% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 50.18 KMac, 0.002% MACs, inplace=True)
#         (conv1): Conv2d(32.77 k, 0.411% Params, 6.42 MMac, 0.221% MACs, 256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 50.18 KMac, 0.002% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 25.09 KMac, 0.001% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 7.23 MMac, 0.249% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         74.56 k, 0.934% Params, 14.7 MMac, 0.507% MACs,
#         (norm1): BatchNorm2d(576, 0.007% Params, 112.9 KMac, 0.004% MACs, 288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 56.45 KMac, 0.002% MACs, inplace=True)
#         (conv1): Conv2d(36.86 k, 0.462% Params, 7.23 MMac, 0.249% MACs, 288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 50.18 KMac, 0.002% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 25.09 KMac, 0.001% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 7.23 MMac, 0.249% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         78.72 k, 0.987% Params, 15.52 MMac, 0.535% MACs,
#         (norm1): BatchNorm2d(640, 0.008% Params, 125.44 KMac, 0.004% MACs, 320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 62.72 KMac, 0.002% MACs, inplace=True)
#         (conv1): Conv2d(40.96 k, 0.513% Params, 8.03 MMac, 0.277% MACs, 320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 50.18 KMac, 0.002% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 25.09 KMac, 0.001% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 7.23 MMac, 0.249% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         82.88 k, 1.039% Params, 16.34 MMac, 0.563% MACs,
#         (norm1): BatchNorm2d(704, 0.009% Params, 137.98 KMac, 0.005% MACs, 352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 68.99 KMac, 0.002% MACs, inplace=True)
#         (conv1): Conv2d(45.06 k, 0.565% Params, 8.83 MMac, 0.305% MACs, 352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 50.18 KMac, 0.002% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 25.09 KMac, 0.001% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 7.23 MMac, 0.249% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         87.04 k, 1.091% Params, 17.16 MMac, 0.592% MACs,
#         (norm1): BatchNorm2d(768, 0.010% Params, 150.53 KMac, 0.005% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 75.26 KMac, 0.003% MACs, inplace=True)
#         (conv1): Conv2d(49.15 k, 0.616% Params, 9.63 MMac, 0.332% MACs, 384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 50.18 KMac, 0.002% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 25.09 KMac, 0.001% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 7.23 MMac, 0.249% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         91.2 k, 1.143% Params, 17.98 MMac, 0.620% MACs,
#         (norm1): BatchNorm2d(832, 0.010% Params, 163.07 KMac, 0.006% MACs, 416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 81.54 KMac, 0.003% MACs, inplace=True)
#         (conv1): Conv2d(53.25 k, 0.667% Params, 10.44 MMac, 0.360% MACs, 416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 50.18 KMac, 0.002% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 25.09 KMac, 0.001% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 7.23 MMac, 0.249% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         95.36 k, 1.195% Params, 18.8 MMac, 0.648% MACs,
#         (norm1): BatchNorm2d(896, 0.011% Params, 175.62 KMac, 0.006% MACs, 448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 87.81 KMac, 0.003% MACs, inplace=True)
#         (conv1): Conv2d(57.34 k, 0.719% Params, 11.24 MMac, 0.388% MACs, 448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 50.18 KMac, 0.002% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 25.09 KMac, 0.001% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 7.23 MMac, 0.249% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         99.52 k, 1.247% Params, 19.63 MMac, 0.677% MACs,
#         (norm1): BatchNorm2d(960, 0.012% Params, 188.16 KMac, 0.006% MACs, 480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 94.08 KMac, 0.003% MACs, inplace=True)
#         (conv1): Conv2d(61.44 k, 0.770% Params, 12.04 MMac, 0.415% MACs, 480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 50.18 KMac, 0.002% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 25.09 KMac, 0.001% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 7.23 MMac, 0.249% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         103.68 k, 1.299% Params, 20.45 MMac, 0.705% MACs,
#         (norm1): BatchNorm2d(1.02 k, 0.013% Params, 200.7 KMac, 0.007% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 100.35 KMac, 0.003% MACs, inplace=True)
#         (conv1): Conv2d(65.54 k, 0.821% Params, 12.85 MMac, 0.443% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 50.18 KMac, 0.002% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 25.09 KMac, 0.001% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 7.23 MMac, 0.249% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         107.84 k, 1.352% Params, 21.27 MMac, 0.733% MACs,
#         (norm1): BatchNorm2d(1.09 k, 0.014% Params, 213.25 KMac, 0.007% MACs, 544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 106.62 KMac, 0.004% MACs, inplace=True)
#         (conv1): Conv2d(69.63 k, 0.873% Params, 13.65 MMac, 0.471% MACs, 544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 50.18 KMac, 0.002% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 25.09 KMac, 0.001% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 7.23 MMac, 0.249% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         112.0 k, 1.404% Params, 22.09 MMac, 0.762% MACs,
#         (norm1): BatchNorm2d(1.15 k, 0.014% Params, 225.79 KMac, 0.008% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 112.9 KMac, 0.004% MACs, inplace=True)
#         (conv1): Conv2d(73.73 k, 0.924% Params, 14.45 MMac, 0.498% MACs, 576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 50.18 KMac, 0.002% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 25.09 KMac, 0.001% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 7.23 MMac, 0.249% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         116.16 k, 1.456% Params, 22.91 MMac, 0.790% MACs,
#         (norm1): BatchNorm2d(1.22 k, 0.015% Params, 238.34 KMac, 0.008% MACs, 608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 119.17 KMac, 0.004% MACs, inplace=True)
#         (conv1): Conv2d(77.82 k, 0.975% Params, 15.25 MMac, 0.526% MACs, 608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 50.18 KMac, 0.002% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 25.09 KMac, 0.001% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 7.23 MMac, 0.249% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         120.32 k, 1.508% Params, 23.73 MMac, 0.818% MACs,
#         (norm1): BatchNorm2d(1.28 k, 0.016% Params, 250.88 KMac, 0.009% MACs, 640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 125.44 KMac, 0.004% MACs, inplace=True)
#         (conv1): Conv2d(81.92 k, 1.027% Params, 16.06 MMac, 0.554% MACs, 640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 50.18 KMac, 0.002% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 25.09 KMac, 0.001% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 7.23 MMac, 0.249% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         124.48 k, 1.560% Params, 24.55 MMac, 0.847% MACs,
#         (norm1): BatchNorm2d(1.34 k, 0.017% Params, 263.42 KMac, 0.009% MACs, 672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 131.71 KMac, 0.005% MACs, inplace=True)
#         (conv1): Conv2d(86.02 k, 1.078% Params, 16.86 MMac, 0.581% MACs, 672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 50.18 KMac, 0.002% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 25.09 KMac, 0.001% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 7.23 MMac, 0.249% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         128.64 k, 1.612% Params, 25.38 MMac, 0.875% MACs,
#         (norm1): BatchNorm2d(1.41 k, 0.018% Params, 275.97 KMac, 0.010% MACs, 704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 137.98 KMac, 0.005% MACs, inplace=True)
#         (conv1): Conv2d(90.11 k, 1.129% Params, 17.66 MMac, 0.609% MACs, 704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 50.18 KMac, 0.002% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 25.09 KMac, 0.001% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 7.23 MMac, 0.249% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         132.8 k, 1.664% Params, 26.2 MMac, 0.903% MACs,
#         (norm1): BatchNorm2d(1.47 k, 0.018% Params, 288.51 KMac, 0.010% MACs, 736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 144.26 KMac, 0.005% MACs, inplace=True)
#         (conv1): Conv2d(94.21 k, 1.181% Params, 18.46 MMac, 0.637% MACs, 736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 50.18 KMac, 0.002% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 25.09 KMac, 0.001% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 7.23 MMac, 0.249% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         136.96 k, 1.717% Params, 27.02 MMac, 0.932% MACs,
#         (norm1): BatchNorm2d(1.54 k, 0.019% Params, 301.06 KMac, 0.010% MACs, 768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 150.53 KMac, 0.005% MACs, inplace=True)
#         (conv1): Conv2d(98.3 k, 1.232% Params, 19.27 MMac, 0.664% MACs, 768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 50.18 KMac, 0.002% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 25.09 KMac, 0.001% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 7.23 MMac, 0.249% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         141.12 k, 1.769% Params, 27.84 MMac, 0.960% MACs,
#         (norm1): BatchNorm2d(1.6 k, 0.020% Params, 313.6 KMac, 0.011% MACs, 800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 156.8 KMac, 0.005% MACs, inplace=True)
#         (conv1): Conv2d(102.4 k, 1.283% Params, 20.07 MMac, 0.692% MACs, 800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 50.18 KMac, 0.002% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 25.09 KMac, 0.001% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 7.23 MMac, 0.249% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         145.28 k, 1.821% Params, 28.66 MMac, 0.988% MACs,
#         (norm1): BatchNorm2d(1.66 k, 0.021% Params, 326.14 KMac, 0.011% MACs, 832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 163.07 KMac, 0.006% MACs, inplace=True)
#         (conv1): Conv2d(106.5 k, 1.335% Params, 20.87 MMac, 0.720% MACs, 832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 50.18 KMac, 0.002% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 25.09 KMac, 0.001% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 7.23 MMac, 0.249% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         149.44 k, 1.873% Params, 29.48 MMac, 1.017% MACs,
#         (norm1): BatchNorm2d(1.73 k, 0.022% Params, 338.69 KMac, 0.012% MACs, 864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 169.34 KMac, 0.006% MACs, inplace=True)
#         (conv1): Conv2d(110.59 k, 1.386% Params, 21.68 MMac, 0.747% MACs, 864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 50.18 KMac, 0.002% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 25.09 KMac, 0.001% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 7.23 MMac, 0.249% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         153.6 k, 1.925% Params, 30.31 MMac, 1.045% MACs,
#         (norm1): BatchNorm2d(1.79 k, 0.022% Params, 351.23 KMac, 0.012% MACs, 896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 175.62 KMac, 0.006% MACs, inplace=True)
#         (conv1): Conv2d(114.69 k, 1.437% Params, 22.48 MMac, 0.775% MACs, 896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 50.18 KMac, 0.002% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 25.09 KMac, 0.001% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 7.23 MMac, 0.249% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         157.76 k, 1.977% Params, 31.13 MMac, 1.073% MACs,
#         (norm1): BatchNorm2d(1.86 k, 0.023% Params, 363.78 KMac, 0.013% MACs, 928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 181.89 KMac, 0.006% MACs, inplace=True)
#         (conv1): Conv2d(118.78 k, 1.489% Params, 23.28 MMac, 0.803% MACs, 928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 50.18 KMac, 0.002% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 25.09 KMac, 0.001% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 7.23 MMac, 0.249% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         161.92 k, 2.029% Params, 31.95 MMac, 1.102% MACs,
#         (norm1): BatchNorm2d(1.92 k, 0.024% Params, 376.32 KMac, 0.013% MACs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 188.16 KMac, 0.006% MACs, inplace=True)
#         (conv1): Conv2d(122.88 k, 1.540% Params, 24.08 MMac, 0.831% MACs, 960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 50.18 KMac, 0.002% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 25.09 KMac, 0.001% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 7.23 MMac, 0.249% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         166.08 k, 2.082% Params, 32.77 MMac, 1.130% MACs,
#         (norm1): BatchNorm2d(1.98 k, 0.025% Params, 388.86 KMac, 0.013% MACs, 992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 194.43 KMac, 0.007% MACs, inplace=True)
#         (conv1): Conv2d(126.98 k, 1.591% Params, 24.89 MMac, 0.858% MACs, 992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 50.18 KMac, 0.002% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 25.09 KMac, 0.001% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 7.23 MMac, 0.249% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition3): _Transition(
#       526.34 k, 6.597% Params, 103.46 MMac, 3.568% MACs,
#       (norm): BatchNorm2d(2.05 k, 0.026% Params, 401.41 KMac, 0.014% MACs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 200.7 KMac, 0.007% MACs, inplace=True)
#       (conv): Conv2d(524.29 k, 6.571% Params, 102.76 MMac, 3.544% MACs, 1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(0, 0.000% Params, 100.35 KMac, 0.003% MACs, kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock4): _DenseBlock(
#       2.16 M, 27.047% Params, 106.44 MMac, 3.670% MACs,
#       (denselayer1): _DenseLayer(
#         103.68 k, 1.299% Params, 5.11 MMac, 0.176% MACs,
#         (norm1): BatchNorm2d(1.02 k, 0.013% Params, 50.18 KMac, 0.002% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 25.09 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(65.54 k, 0.821% Params, 3.21 MMac, 0.111% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 12.54 KMac, 0.000% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 6.27 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 1.81 MMac, 0.062% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         107.84 k, 1.352% Params, 5.32 MMac, 0.183% MACs,
#         (norm1): BatchNorm2d(1.09 k, 0.014% Params, 53.31 KMac, 0.002% MACs, 544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 26.66 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(69.63 k, 0.873% Params, 3.41 MMac, 0.118% MACs, 544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 12.54 KMac, 0.000% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 6.27 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 1.81 MMac, 0.062% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         112.0 k, 1.404% Params, 5.52 MMac, 0.190% MACs,
#         (norm1): BatchNorm2d(1.15 k, 0.014% Params, 56.45 KMac, 0.002% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 28.22 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(73.73 k, 0.924% Params, 3.61 MMac, 0.125% MACs, 576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 12.54 KMac, 0.000% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 6.27 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 1.81 MMac, 0.062% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         116.16 k, 1.456% Params, 5.73 MMac, 0.198% MACs,
#         (norm1): BatchNorm2d(1.22 k, 0.015% Params, 59.58 KMac, 0.002% MACs, 608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 29.79 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(77.82 k, 0.975% Params, 3.81 MMac, 0.132% MACs, 608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 12.54 KMac, 0.000% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 6.27 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 1.81 MMac, 0.062% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         120.32 k, 1.508% Params, 5.93 MMac, 0.205% MACs,
#         (norm1): BatchNorm2d(1.28 k, 0.016% Params, 62.72 KMac, 0.002% MACs, 640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 31.36 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(81.92 k, 1.027% Params, 4.01 MMac, 0.138% MACs, 640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 12.54 KMac, 0.000% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 6.27 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 1.81 MMac, 0.062% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         124.48 k, 1.560% Params, 6.14 MMac, 0.212% MACs,
#         (norm1): BatchNorm2d(1.34 k, 0.017% Params, 65.86 KMac, 0.002% MACs, 672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 32.93 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(86.02 k, 1.078% Params, 4.21 MMac, 0.145% MACs, 672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 12.54 KMac, 0.000% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 6.27 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 1.81 MMac, 0.062% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         128.64 k, 1.612% Params, 6.34 MMac, 0.219% MACs,
#         (norm1): BatchNorm2d(1.41 k, 0.018% Params, 68.99 KMac, 0.002% MACs, 704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 34.5 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(90.11 k, 1.129% Params, 4.42 MMac, 0.152% MACs, 704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 12.54 KMac, 0.000% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 6.27 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 1.81 MMac, 0.062% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         132.8 k, 1.664% Params, 6.55 MMac, 0.226% MACs,
#         (norm1): BatchNorm2d(1.47 k, 0.018% Params, 72.13 KMac, 0.002% MACs, 736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 36.06 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(94.21 k, 1.181% Params, 4.62 MMac, 0.159% MACs, 736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 12.54 KMac, 0.000% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 6.27 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 1.81 MMac, 0.062% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         136.96 k, 1.717% Params, 6.75 MMac, 0.233% MACs,
#         (norm1): BatchNorm2d(1.54 k, 0.019% Params, 75.26 KMac, 0.003% MACs, 768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 37.63 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(98.3 k, 1.232% Params, 4.82 MMac, 0.166% MACs, 768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 12.54 KMac, 0.000% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 6.27 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 1.81 MMac, 0.062% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         141.12 k, 1.769% Params, 6.96 MMac, 0.240% MACs,
#         (norm1): BatchNorm2d(1.6 k, 0.020% Params, 78.4 KMac, 0.003% MACs, 800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 39.2 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(102.4 k, 1.283% Params, 5.02 MMac, 0.173% MACs, 800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 12.54 KMac, 0.000% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 6.27 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 1.81 MMac, 0.062% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         145.28 k, 1.821% Params, 7.17 MMac, 0.247% MACs,
#         (norm1): BatchNorm2d(1.66 k, 0.021% Params, 81.54 KMac, 0.003% MACs, 832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 40.77 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(106.5 k, 1.335% Params, 5.22 MMac, 0.180% MACs, 832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 12.54 KMac, 0.000% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 6.27 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 1.81 MMac, 0.062% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         149.44 k, 1.873% Params, 7.37 MMac, 0.254% MACs,
#         (norm1): BatchNorm2d(1.73 k, 0.022% Params, 84.67 KMac, 0.003% MACs, 864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 42.34 KMac, 0.001% MACs, inplace=True)
#         (conv1): Conv2d(110.59 k, 1.386% Params, 5.42 MMac, 0.187% MACs, 864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 12.54 KMac, 0.000% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 6.27 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 1.81 MMac, 0.062% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         153.6 k, 1.925% Params, 7.58 MMac, 0.261% MACs,
#         (norm1): BatchNorm2d(1.79 k, 0.022% Params, 87.81 KMac, 0.003% MACs, 896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 43.9 KMac, 0.002% MACs, inplace=True)
#         (conv1): Conv2d(114.69 k, 1.437% Params, 5.62 MMac, 0.194% MACs, 896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 12.54 KMac, 0.000% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 6.27 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 1.81 MMac, 0.062% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         157.76 k, 1.977% Params, 7.78 MMac, 0.268% MACs,
#         (norm1): BatchNorm2d(1.86 k, 0.023% Params, 90.94 KMac, 0.003% MACs, 928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 45.47 KMac, 0.002% MACs, inplace=True)
#         (conv1): Conv2d(118.78 k, 1.489% Params, 5.82 MMac, 0.201% MACs, 928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 12.54 KMac, 0.000% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 6.27 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 1.81 MMac, 0.062% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         161.92 k, 2.029% Params, 7.99 MMac, 0.275% MACs,
#         (norm1): BatchNorm2d(1.92 k, 0.024% Params, 94.08 KMac, 0.003% MACs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 47.04 KMac, 0.002% MACs, inplace=True)
#         (conv1): Conv2d(122.88 k, 1.540% Params, 6.02 MMac, 0.208% MACs, 960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 12.54 KMac, 0.000% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 6.27 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 1.81 MMac, 0.062% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         166.08 k, 2.082% Params, 8.19 MMac, 0.283% MACs,
#         (norm1): BatchNorm2d(1.98 k, 0.025% Params, 97.22 KMac, 0.003% MACs, 992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(0, 0.000% Params, 48.61 KMac, 0.002% MACs, inplace=True)
#         (conv1): Conv2d(126.98 k, 1.591% Params, 6.22 MMac, 0.215% MACs, 992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(256, 0.003% Params, 12.54 KMac, 0.000% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(0, 0.000% Params, 6.27 KMac, 0.000% MACs, inplace=True)
#         (conv2): Conv2d(36.86 k, 0.462% Params, 1.81 MMac, 0.062% MACs, 128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (norm5): BatchNorm2d(2.05 k, 0.026% Params, 100.35 KMac, 0.003% MACs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Linear(1.02 M, 12.846% Params, 1.02 MMac, 0.035% MACs, in_features=1024, out_features=1000, bias=True)
# )
# FLOPs: 2.9 GMac, Parameters: 7.98 M

# %%
from ptflops import get_model_complexity_info

model = models.squeezenet1_0(pretrained=True)

macs, params = get_model_complexity_info(model, (3, 224, 224), as_strings=True, print_per_layer_stat=True)
print(f"FLOPs: {macs}, Parameters: {params}")
# Out:
# C:\Users\mruba\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=SqueezeNet1_0_Weights.IMAGENET1K_V1`. You can also use `weights=SqueezeNet1_0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# SqueezeNet(
#   1.25 M, 100.000% Params, 830.05 MMac, 99.190% MACs,
#   (features): Sequential(
#     735.42 k, 58.908% Params, 743.01 MMac, 88.790% MACs,
#     (0): Conv2d(14.21 k, 1.138% Params, 168.81 MMac, 20.172% MACs, 3, 96, kernel_size=(7, 7), stride=(2, 2))
#     (1): ReLU(0, 0.000% Params, 1.14 MMac, 0.136% MACs, inplace=True)
#     (2): MaxPool2d(0, 0.000% Params, 1.14 MMac, 0.136% MACs, kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (3): Fire(
#       11.92 k, 0.955% Params, 35.18 MMac, 4.204% MACs,
#       (squeeze): Conv2d(1.55 k, 0.124% Params, 4.53 MMac, 0.541% MACs, 96, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(0, 0.000% Params, 46.66 KMac, 0.006% MACs, inplace=True)
#       (expand1x1): Conv2d(1.09 k, 0.087% Params, 3.17 MMac, 0.379% MACs, 16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(0, 0.000% Params, 186.62 KMac, 0.022% MACs, inplace=True)
#       (expand3x3): Conv2d(9.28 k, 0.743% Params, 27.06 MMac, 3.234% MACs, 16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(0, 0.000% Params, 186.62 KMac, 0.022% MACs, inplace=True)
#     )
#     (4): Fire(
#       12.43 k, 0.996% Params, 36.67 MMac, 4.382% MACs,
#       (squeeze): Conv2d(2.06 k, 0.165% Params, 6.02 MMac, 0.719% MACs, 128, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(0, 0.000% Params, 46.66 KMac, 0.006% MACs, inplace=True)
#       (expand1x1): Conv2d(1.09 k, 0.087% Params, 3.17 MMac, 0.379% MACs, 16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(0, 0.000% Params, 186.62 KMac, 0.022% MACs, inplace=True)
#       (expand3x3): Conv2d(9.28 k, 0.743% Params, 27.06 MMac, 3.234% MACs, 16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(0, 0.000% Params, 186.62 KMac, 0.022% MACs, inplace=True)
#     )
#     (5): Fire(
#       45.34 k, 3.632% Params, 133.06 MMac, 15.901% MACs,
#       (squeeze): Conv2d(4.13 k, 0.331% Params, 12.04 MMac, 1.438% MACs, 128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(0, 0.000% Params, 93.31 KMac, 0.011% MACs, inplace=True)
#       (expand1x1): Conv2d(4.22 k, 0.338% Params, 12.32 MMac, 1.472% MACs, 32, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(0, 0.000% Params, 373.25 KMac, 0.045% MACs, inplace=True)
#       (expand3x3): Conv2d(36.99 k, 2.963% Params, 107.87 MMac, 12.890% MACs, 32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(0, 0.000% Params, 373.25 KMac, 0.045% MACs, inplace=True)
#     )
#     (6): MaxPool2d(0, 0.000% Params, 746.5 KMac, 0.089% MACs, kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (7): Fire(
#       49.44 k, 3.960% Params, 36.25 MMac, 4.332% MACs,
#       (squeeze): Conv2d(8.22 k, 0.659% Params, 6.0 MMac, 0.716% MACs, 256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(0, 0.000% Params, 23.33 KMac, 0.003% MACs, inplace=True)
#       (expand1x1): Conv2d(4.22 k, 0.338% Params, 3.08 MMac, 0.368% MACs, 32, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(0, 0.000% Params, 93.31 KMac, 0.011% MACs, inplace=True)
#       (expand3x3): Conv2d(36.99 k, 2.963% Params, 26.97 MMac, 3.223% MACs, 32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(0, 0.000% Params, 93.31 KMac, 0.011% MACs, inplace=True)
#     )
#     (8): Fire(
#       104.88 k, 8.401% Params, 76.77 MMac, 9.174% MACs,
#       (squeeze): Conv2d(12.34 k, 0.988% Params, 8.99 MMac, 1.075% MACs, 256, 48, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(0, 0.000% Params, 34.99 KMac, 0.004% MACs, inplace=True)
#       (expand1x1): Conv2d(9.41 k, 0.754% Params, 6.86 MMac, 0.820% MACs, 48, 192, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(0, 0.000% Params, 139.97 KMac, 0.017% MACs, inplace=True)
#       (expand3x3): Conv2d(83.14 k, 6.659% Params, 60.61 MMac, 7.242% MACs, 48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(0, 0.000% Params, 139.97 KMac, 0.017% MACs, inplace=True)
#     )
#     (9): Fire(
#       111.02 k, 8.893% Params, 81.25 MMac, 9.710% MACs,
#       (squeeze): Conv2d(18.48 k, 1.480% Params, 13.47 MMac, 1.610% MACs, 384, 48, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(0, 0.000% Params, 34.99 KMac, 0.004% MACs, inplace=True)
#       (expand1x1): Conv2d(9.41 k, 0.754% Params, 6.86 MMac, 0.820% MACs, 48, 192, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(0, 0.000% Params, 139.97 KMac, 0.017% MACs, inplace=True)
#       (expand3x3): Conv2d(83.14 k, 6.659% Params, 60.61 MMac, 7.242% MACs, 48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(0, 0.000% Params, 139.97 KMac, 0.017% MACs, inplace=True)
#     )
#     (10): Fire(
#       188.99 k, 15.138% Params, 138.2 MMac, 16.514% MACs,
#       (squeeze): Conv2d(24.64 k, 1.974% Params, 17.96 MMac, 2.147% MACs, 384, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(0, 0.000% Params, 46.66 KMac, 0.006% MACs, inplace=True)
#       (expand1x1): Conv2d(16.64 k, 1.333% Params, 12.13 MMac, 1.450% MACs, 64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(0, 0.000% Params, 186.62 KMac, 0.022% MACs, inplace=True)
#       (expand3x3): Conv2d(147.71 k, 11.832% Params, 107.68 MMac, 12.868% MACs, 64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(0, 0.000% Params, 186.62 KMac, 0.022% MACs, inplace=True)
#     )
#     (11): MaxPool2d(0, 0.000% Params, 373.25 KMac, 0.045% MACs, kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (12): Fire(
#       197.18 k, 15.795% Params, 33.42 MMac, 3.994% MACs,
#       (squeeze): Conv2d(32.83 k, 2.630% Params, 5.55 MMac, 0.663% MACs, 512, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(0, 0.000% Params, 10.82 KMac, 0.001% MACs, inplace=True)
#       (expand1x1): Conv2d(16.64 k, 1.333% Params, 2.81 MMac, 0.336% MACs, 64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(0, 0.000% Params, 43.26 KMac, 0.005% MACs, inplace=True)
#       (expand3x3): Conv2d(147.71 k, 11.832% Params, 24.96 MMac, 2.983% MACs, 64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(0, 0.000% Params, 43.26 KMac, 0.005% MACs, inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     513.0 k, 41.092% Params, 87.03 MMac, 10.401% MACs,
#     (0): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.5, inplace=False)
#     (1): Conv2d(513.0 k, 41.092% Params, 86.7 MMac, 10.360% MACs, 512, 1000, kernel_size=(1, 1), stride=(1, 1))
#     (2): ReLU(0, 0.000% Params, 169.0 KMac, 0.020% MACs, inplace=True)
#     (3): AdaptiveAvgPool2d(0, 0.000% Params, 169.0 KMac, 0.020% MACs, output_size=(1, 1))
#   )
# )
# FLOPs: 836.82 MMac, Parameters: 1.25 M

# %%
from ptflops import get_model_complexity_info

model = models.alexnet(pretrained=True)

macs, params = get_model_complexity_info(model, (3, 224, 224), as_strings=True, print_per_layer_stat=True)
print(f"FLOPs: {macs}, Parameters: {params}")
# Out:
# C:\Users\mruba\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# AlexNet(
#   61.1 M, 100.000% Params, 715.56 MMac, 99.877% MACs,
#   (features): Sequential(
#     2.47 M, 4.042% Params, 656.91 MMac, 91.691% MACs,
#     (0): Conv2d(23.3 k, 0.038% Params, 70.47 MMac, 9.836% MACs, 3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(0, 0.000% Params, 193.6 KMac, 0.027% MACs, inplace=True)
#     (2): MaxPool2d(0, 0.000% Params, 193.6 KMac, 0.027% MACs, kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(307.39 k, 0.503% Params, 224.09 MMac, 31.278% MACs, 64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(0, 0.000% Params, 139.97 KMac, 0.020% MACs, inplace=True)
#     (5): MaxPool2d(0, 0.000% Params, 139.97 KMac, 0.020% MACs, kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(663.94 k, 1.087% Params, 112.21 MMac, 15.661% MACs, 192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(0, 0.000% Params, 64.9 KMac, 0.009% MACs, inplace=True)
#     (8): Conv2d(884.99 k, 1.448% Params, 149.56 MMac, 20.876% MACs, 384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(0, 0.000% Params, 43.26 KMac, 0.006% MACs, inplace=True)
#     (10): Conv2d(590.08 k, 0.966% Params, 99.72 MMac, 13.919% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(0, 0.000% Params, 43.26 KMac, 0.006% MACs, inplace=True)
#     (12): MaxPool2d(0, 0.000% Params, 43.26 KMac, 0.006% MACs, kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 9.22 KMac, 0.001% MACs, output_size=(6, 6))
#   (classifier): Sequential(
#     58.63 M, 95.958% Params, 58.64 MMac, 8.185% MACs,
#     (0): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.5, inplace=False)
#     (1): Linear(37.75 M, 61.788% Params, 37.75 MMac, 5.269% MACs, in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(0, 0.000% Params, 4.1 KMac, 0.001% MACs, inplace=True)
#     (3): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.5, inplace=False)
#     (4): Linear(16.78 M, 27.465% Params, 16.78 MMac, 2.342% MACs, in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(0, 0.000% Params, 4.1 KMac, 0.001% MACs, inplace=True)
#     (6): Linear(4.1 M, 6.705% Params, 4.1 MMac, 0.572% MACs, in_features=4096, out_features=1000, bias=True)
#   )
# )
# FLOPs: 716.44 MMac, Parameters: 61.1 M

# %%
from ptflops import get_model_complexity_info

model = models.resnext50_32x4d(pretrained=True)

macs, params = get_model_complexity_info(model, (3, 224, 224), as_strings=True, print_per_layer_stat=True)
print(f"FLOPs: {macs}, Parameters: {params}")
# Out:
# C:\Users\mruba\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNeXt50_32X4D_Weights.IMAGENET1K_V1`. You can also use `weights=ResNeXt50_32X4D_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ResNet(
#   25.03 M, 100.000% Params, 4.27 GMac, 99.678% MACs,
#   (conv1): Conv2d(9.41 k, 0.038% Params, 118.01 MMac, 2.753% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(128, 0.001% Params, 1.61 MMac, 0.037% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(0, 0.000% Params, 802.82 KMac, 0.019% MACs, inplace=True)
#   (maxpool): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.019% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     205.82 k, 0.822% Params, 650.28 MMac, 15.169% MACs,
#     (0): Bottleneck(
#       63.49 k, 0.254% Params, 200.7 MMac, 4.682% MACs,
#       (conv1): Conv2d(8.19 k, 0.033% Params, 25.69 MMac, 0.599% MACs, 64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, 0.001% Params, 802.82 KMac, 0.019% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(4.61 k, 0.018% Params, 14.45 MMac, 0.337% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(256, 0.001% Params, 802.82 KMac, 0.019% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(32.77 k, 0.131% Params, 102.76 MMac, 2.397% MACs, 128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, 0.002% Params, 1.61 MMac, 0.037% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 1.61 MMac, 0.037% MACs, inplace=True)
#       (downsample): Sequential(
#         16.9 k, 0.068% Params, 52.99 MMac, 1.236% MACs,
#         (0): Conv2d(16.38 k, 0.065% Params, 51.38 MMac, 1.199% MACs, 64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(512, 0.002% Params, 1.61 MMac, 0.037% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       71.17 k, 0.284% Params, 224.79 MMac, 5.244% MACs,
#       (conv1): Conv2d(32.77 k, 0.131% Params, 102.76 MMac, 2.397% MACs, 256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, 0.001% Params, 802.82 KMac, 0.019% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(4.61 k, 0.018% Params, 14.45 MMac, 0.337% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(256, 0.001% Params, 802.82 KMac, 0.019% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(32.77 k, 0.131% Params, 102.76 MMac, 2.397% MACs, 128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, 0.002% Params, 1.61 MMac, 0.037% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 1.61 MMac, 0.037% MACs, inplace=True)
#     )
#     (2): Bottleneck(
#       71.17 k, 0.284% Params, 224.79 MMac, 5.244% MACs,
#       (conv1): Conv2d(32.77 k, 0.131% Params, 102.76 MMac, 2.397% MACs, 256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, 0.001% Params, 802.82 KMac, 0.019% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(4.61 k, 0.018% Params, 14.45 MMac, 0.337% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(256, 0.001% Params, 802.82 KMac, 0.019% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(32.77 k, 0.131% Params, 102.76 MMac, 2.397% MACs, 128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, 0.002% Params, 1.61 MMac, 0.037% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 1.61 MMac, 0.037% MACs, inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     1.2 M, 4.783% Params, 1.1 GMac, 25.605% MACs,
#     (0): Bottleneck(
#       349.18 k, 1.395% Params, 430.51 MMac, 10.043% MACs,
#       (conv1): Conv2d(65.54 k, 0.262% Params, 205.52 MMac, 4.794% MACs, 256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, 0.002% Params, 1.61 MMac, 0.037% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(18.43 k, 0.074% Params, 14.45 MMac, 0.337% MACs, 256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(512, 0.002% Params, 401.41 KMac, 0.009% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(131.07 k, 0.524% Params, 102.76 MMac, 2.397% MACs, 256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1.02 k, 0.004% Params, 802.82 KMac, 0.019% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 1.4 MMac, 0.033% MACs, inplace=True)
#       (downsample): Sequential(
#         132.1 k, 0.528% Params, 103.56 MMac, 2.416% MACs,
#         (0): Conv2d(131.07 k, 0.524% Params, 102.76 MMac, 2.397% MACs, 256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1.02 k, 0.004% Params, 802.82 KMac, 0.019% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       282.62 k, 1.129% Params, 222.38 MMac, 5.187% MACs,
#       (conv1): Conv2d(131.07 k, 0.524% Params, 102.76 MMac, 2.397% MACs, 512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, 0.002% Params, 401.41 KMac, 0.009% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(18.43 k, 0.074% Params, 14.45 MMac, 0.337% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(512, 0.002% Params, 401.41 KMac, 0.009% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(131.07 k, 0.524% Params, 102.76 MMac, 2.397% MACs, 256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1.02 k, 0.004% Params, 802.82 KMac, 0.019% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 802.82 KMac, 0.019% MACs, inplace=True)
#     )
#     (2): Bottleneck(
#       282.62 k, 1.129% Params, 222.38 MMac, 5.187% MACs,
#       (conv1): Conv2d(131.07 k, 0.524% Params, 102.76 MMac, 2.397% MACs, 512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, 0.002% Params, 401.41 KMac, 0.009% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(18.43 k, 0.074% Params, 14.45 MMac, 0.337% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(512, 0.002% Params, 401.41 KMac, 0.009% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(131.07 k, 0.524% Params, 102.76 MMac, 2.397% MACs, 256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1.02 k, 0.004% Params, 802.82 KMac, 0.019% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 802.82 KMac, 0.019% MACs, inplace=True)
#     )
#     (3): Bottleneck(
#       282.62 k, 1.129% Params, 222.38 MMac, 5.187% MACs,
#       (conv1): Conv2d(131.07 k, 0.524% Params, 102.76 MMac, 2.397% MACs, 512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, 0.002% Params, 401.41 KMac, 0.009% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(18.43 k, 0.074% Params, 14.45 MMac, 0.337% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(512, 0.002% Params, 401.41 KMac, 0.009% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(131.07 k, 0.524% Params, 102.76 MMac, 2.397% MACs, 256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1.02 k, 0.004% Params, 802.82 KMac, 0.019% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 802.82 KMac, 0.019% MACs, inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     7.02 M, 28.058% Params, 1.53 GMac, 35.781% MACs,
#     (0): Bottleneck(
#       1.39 M, 5.556% Params, 428.0 MMac, 9.984% MACs,
#       (conv1): Conv2d(262.14 k, 1.047% Params, 205.52 MMac, 4.794% MACs, 512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1.02 k, 0.004% Params, 802.82 KMac, 0.019% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(73.73 k, 0.295% Params, 14.45 MMac, 0.337% MACs, 512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1.02 k, 0.004% Params, 200.7 KMac, 0.005% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(524.29 k, 2.095% Params, 102.76 MMac, 2.397% MACs, 512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2.05 k, 0.008% Params, 401.41 KMac, 0.009% MACs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 702.46 KMac, 0.016% MACs, inplace=True)
#       (downsample): Sequential(
#         526.34 k, 2.103% Params, 103.16 MMac, 2.406% MACs,
#         (0): Conv2d(524.29 k, 2.095% Params, 102.76 MMac, 2.397% MACs, 512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2.05 k, 0.008% Params, 401.41 KMac, 0.009% MACs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       1.13 M, 4.500% Params, 221.18 MMac, 5.159% MACs,
#       (conv1): Conv2d(524.29 k, 2.095% Params, 102.76 MMac, 2.397% MACs, 1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1.02 k, 0.004% Params, 200.7 KMac, 0.005% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(73.73 k, 0.295% Params, 14.45 MMac, 0.337% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1.02 k, 0.004% Params, 200.7 KMac, 0.005% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(524.29 k, 2.095% Params, 102.76 MMac, 2.397% MACs, 512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2.05 k, 0.008% Params, 401.41 KMac, 0.009% MACs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 401.41 KMac, 0.009% MACs, inplace=True)
#     )
#     (2): Bottleneck(
#       1.13 M, 4.500% Params, 221.18 MMac, 5.159% MACs,
#       (conv1): Conv2d(524.29 k, 2.095% Params, 102.76 MMac, 2.397% MACs, 1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1.02 k, 0.004% Params, 200.7 KMac, 0.005% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(73.73 k, 0.295% Params, 14.45 MMac, 0.337% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1.02 k, 0.004% Params, 200.7 KMac, 0.005% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(524.29 k, 2.095% Params, 102.76 MMac, 2.397% MACs, 512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2.05 k, 0.008% Params, 401.41 KMac, 0.009% MACs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 401.41 KMac, 0.009% MACs, inplace=True)
#     )
#     (3): Bottleneck(
#       1.13 M, 4.500% Params, 221.18 MMac, 5.159% MACs,
#       (conv1): Conv2d(524.29 k, 2.095% Params, 102.76 MMac, 2.397% MACs, 1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1.02 k, 0.004% Params, 200.7 KMac, 0.005% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(73.73 k, 0.295% Params, 14.45 MMac, 0.337% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1.02 k, 0.004% Params, 200.7 KMac, 0.005% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(524.29 k, 2.095% Params, 102.76 MMac, 2.397% MACs, 512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2.05 k, 0.008% Params, 401.41 KMac, 0.009% MACs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 401.41 KMac, 0.009% MACs, inplace=True)
#     )
#     (4): Bottleneck(
#       1.13 M, 4.500% Params, 221.18 MMac, 5.159% MACs,
#       (conv1): Conv2d(524.29 k, 2.095% Params, 102.76 MMac, 2.397% MACs, 1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1.02 k, 0.004% Params, 200.7 KMac, 0.005% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(73.73 k, 0.295% Params, 14.45 MMac, 0.337% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1.02 k, 0.004% Params, 200.7 KMac, 0.005% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(524.29 k, 2.095% Params, 102.76 MMac, 2.397% MACs, 512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2.05 k, 0.008% Params, 401.41 KMac, 0.009% MACs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 401.41 KMac, 0.009% MACs, inplace=True)
#     )
#     (5): Bottleneck(
#       1.13 M, 4.500% Params, 221.18 MMac, 5.159% MACs,
#       (conv1): Conv2d(524.29 k, 2.095% Params, 102.76 MMac, 2.397% MACs, 1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1.02 k, 0.004% Params, 200.7 KMac, 0.005% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(73.73 k, 0.295% Params, 14.45 MMac, 0.337% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(1.02 k, 0.004% Params, 200.7 KMac, 0.005% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(524.29 k, 2.095% Params, 102.76 MMac, 2.397% MACs, 512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2.05 k, 0.008% Params, 401.41 KMac, 0.009% MACs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 401.41 KMac, 0.009% MACs, inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     14.54 M, 58.112% Params, 867.89 MMac, 20.245% MACs,
#     (0): Bottleneck(
#       5.55 M, 22.175% Params, 426.75 MMac, 9.955% MACs,
#       (conv1): Conv2d(1.05 M, 4.189% Params, 205.52 MMac, 4.794% MACs, 1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(2.05 k, 0.008% Params, 401.41 KMac, 0.009% MACs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(294.91 k, 1.178% Params, 14.45 MMac, 0.337% MACs, 1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(2.05 k, 0.008% Params, 100.35 KMac, 0.002% MACs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(2.1 M, 8.379% Params, 102.76 MMac, 2.397% MACs, 1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(4.1 k, 0.016% Params, 200.7 KMac, 0.005% MACs, 2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 351.23 KMac, 0.008% MACs, inplace=True)
#       (downsample): Sequential(
#         2.1 M, 8.395% Params, 102.96 MMac, 2.402% MACs,
#         (0): Conv2d(2.1 M, 8.379% Params, 102.76 MMac, 2.397% MACs, 1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(4.1 k, 0.016% Params, 200.7 KMac, 0.005% MACs, 2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       4.5 M, 17.969% Params, 220.57 MMac, 5.145% MACs,
#       (conv1): Conv2d(2.1 M, 8.379% Params, 102.76 MMac, 2.397% MACs, 2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(2.05 k, 0.008% Params, 100.35 KMac, 0.002% MACs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(294.91 k, 1.178% Params, 14.45 MMac, 0.337% MACs, 1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(2.05 k, 0.008% Params, 100.35 KMac, 0.002% MACs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(2.1 M, 8.379% Params, 102.76 MMac, 2.397% MACs, 1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(4.1 k, 0.016% Params, 200.7 KMac, 0.005% MACs, 2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 200.7 KMac, 0.005% MACs, inplace=True)
#     )
#     (2): Bottleneck(
#       4.5 M, 17.969% Params, 220.57 MMac, 5.145% MACs,
#       (conv1): Conv2d(2.1 M, 8.379% Params, 102.76 MMac, 2.397% MACs, 2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(2.05 k, 0.008% Params, 100.35 KMac, 0.002% MACs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(294.91 k, 1.178% Params, 14.45 MMac, 0.337% MACs, 1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (bn2): BatchNorm2d(2.05 k, 0.008% Params, 100.35 KMac, 0.002% MACs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(2.1 M, 8.379% Params, 102.76 MMac, 2.397% MACs, 1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(4.1 k, 0.016% Params, 200.7 KMac, 0.005% MACs, 2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 200.7 KMac, 0.005% MACs, inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 100.35 KMac, 0.002% MACs, output_size=(1, 1))
#   (fc): Linear(2.05 M, 8.187% Params, 2.05 MMac, 0.048% MACs, in_features=2048, out_features=1000, bias=True)
# )
# FLOPs: 4.29 GMac, Parameters: 25.03 M
